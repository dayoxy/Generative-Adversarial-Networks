# %% [markdown]
# <a href="https://colab.research.google.com/github/dayoxy/Generative-Adversarial-Networks/blob/main/Copy_of_dayo_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GAN's using pyTorch.
#
#
#
# Automatically downloading the MNIST dataset to my specified directory.
#
#
#
#
# Generator and Discriminator models, training, visualization and comparision.

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 27.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
pip install torchvision matplotlib numpy
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.5.1+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import os
import numpy as np
import torch.optim as optim

from torchvision import datasets, transforms, utils

# %% [markdown]
# Hyperparameters and training

# %%
latent_dim = 100        # Dimension of latent
batch_size = 128         # Batch size during training
feature_map_size = 28         #feature map size
num_epochs = 200        # Number of training epochs
learning_rate = 0.0002  # Optimizer learning rate
beta1 = 0.5             # hyperparameter for Adam
beta2 = 0.999           # hyperparameter for Adam

# %%
#Checking for GPU and modifying
print("CUDA Available:", torch.cuda.is_available())
print("GPU Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")


device = torch.device("cpu")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# CUDA Available: True
# GPU Device Name: Tesla T4
# Using device: cuda:0

# %% [markdown]
# Loading Dataset

# %%
#Defining the transformation pipeline to ensure proper scaling for images
transform = transforms.Compose([
    transforms.Resize(28),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5))     #Normalizing the images
])

# %%
data_path = r"C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw"
dataset = datasets.MNIST(root=data_path, train=True, transform=transform, download=True)
#MNIST dataset automatically downloaded from Yann LeCun website to my specified directory
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 4.86MB/s]
# Extracting C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/train-images-idx3-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 66.1kB/s]
# Extracting C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/train-labels-idx1-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:06<00:00, 245kB/s]
# Extracting C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/t10k-images-idx3-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.70MB/s]
# Extracting C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw/t10k-labels-idx1-ubyte.gz to C:\Users\HP\OneDrive\Documents\GAN's Project\data\raw/MNIST/raw

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
#using torchvision MNIST datatset loader.

# %%
# os.makedirs("generated_images")

#created folder to save generated images from the generator
output_dir = "generated_images"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
def show_images(tensor, title=None):
    grid = utils.make_grid(tensor, normalize=True)
    plt.figure(figsize=(8, 8))
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    if title:
        plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# GAN's Architecture

# %%
# Generator Model: Generates fake images
class Generator(nn.Module):
    def __init__(self, latent_dim, img_channels=1):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 128, kernel_size=7, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, img_channels, kernel_size=4, stride=2, padding=1, bias=False),
            nn.Tanh()  # Output value using Tanh
        )

    def forward(self, z):
        z = z.view(z.size(0), z.size(1), 1, 1)
        return self.main(z)

# %%
noise = torch.randn(batch_size, latent_dim, device=device)

# %%
#Discriminator Model: Distinguishes between the real and generated images.

class Discriminator(nn.Module):
    def __init__ (self, img_channels=1, feature_map_size=64):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(img_channels, feature_map_size, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(feature_map_size, feature_map_size * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(feature_map_size * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(feature_map_size * 2, feature_map_size * 4, kernel_size=3, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(feature_map_size * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(feature_map_size * 4, 1, kernel_size=5, stride=1, padding=0, bias=False),
            nn.Sigmoid()  #Output probablity.
        )

    def forward(self, input):
        return self.main(input).view(-1, 1).squeeze(1)

# %%
#Instantiate models and move to device
latent_dim = 100
netGen = Generator(latent_dim=latent_dim, img_channels=1).to(device)
netDis = Discriminator(img_channels=1, feature_map_size=64).to(device)

# %%
# Binary Cross Entropy Loss Function and Adam Optimizer
criterion = nn.BCELoss()
optimizerGen = optim.Adam(netGen.parameters(), lr=learning_rate, betas=(beta1, beta2))
optimizerDis = optim.Adam(netDis.parameters(), lr=learning_rate, betas=(beta1, beta2))

# %%
# Labelling for Real and Fake images
real_label = 1.0
fake_label = 0.0

# %%
# Creating label tensors
real_labels = torch.full((batch_size,), 1.0, dtype=torch.float, device=device)
fake_labels = torch.full((batch_size,), 0.0, dtype=torch.float, device=device)

# %%
print("Starting GAN training...")

# Recording Generator and Discriminator Loss
Gen_losses = []
Dis_losses = []

for epoch in range(num_epochs):
    for i, (real_images, _) in enumerate(dataloader):
        b_size = real_images.size(0)
        real_images = real_images.to(device)
        # Creating label tensors using predefined values
        real_labels = torch.full((b_size,), real_label, dtype=torch.float, device=device)
        fake_labels = torch.full((b_size,), fake_label, dtype=torch.float, device=device)

        # Discriminator Training
        try:
            netDis.zero_grad()
            # Train with real images
            output_real = netDis(real_images).view(-1)
            lossD_real = criterion(output_real, real_labels)
            lossD_real.backward()

            # Train with fake images
            noise = torch.randn(b_size, latent_dim, device=device)
            fake_images = netGen(noise)
            output_fake = netDis(fake_images.detach()).view(-1)
            lossD_fake = criterion(output_fake, fake_labels)
            lossD_fake.backward()

            # Combined loss
            lossD = lossD_real + lossD_fake
            optimizerDis.step()

        except Exception as e:
            print(f"Error in discriminator training: {str(e)}")
            continue

        # Generator Training
        netGen.zero_grad()
        output = netDis(fake_images).view(-1)
        lossG = criterion(output, real_labels)
        lossG.backward()
        optimizerGen.step()

        # Recording Values of Loss for both Generator and Discriminator
        Gen_losses.append(lossG.item())
        Dis_losses.append(lossD.item())

        if i % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{i}/{len(dataloader)}] - Loss_D: {lossD.item():.4f}, Loss_G: {lossG.item():.4f}")

    # Saving images generated at the current epoch
    with torch.no_grad():
        fixed_noise = torch.randn(64, latent_dim, device=device)
        fake_imgs_epoch = netGen(fixed_noise).detach().cpu()
    grid = utils.make_grid(fake_imgs_epoch, nrow=8, normalize=True)
    plt.figure(figsize=(8,8))
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.title(f"Generated Images - Epoch {epoch+1}")
    plt.axis("off")
    plt.savefig(f"generated_images/epoch_{epoch+1}.png")
    plt.close()

print("Training finished.")
# Out:
# Starting GAN training...
# Epoch [1/200], Batch [0/469] - Loss_D: 1.5221, Loss_G: 0.9432
# Epoch [1/200], Batch [100/469] - Loss_D: 0.5337, Loss_G: 1.4352
# Epoch [1/200], Batch [200/469] - Loss_D: 0.7132, Loss_G: 2.2017
# Epoch [1/200], Batch [300/469] - Loss_D: 0.4539, Loss_G: 2.3953
# Epoch [1/200], Batch [400/469] - Loss_D: 0.2914, Loss_G: 2.9309
# Epoch [2/200], Batch [0/469] - Loss_D: 0.4206, Loss_G: 2.1636
# Epoch [2/200], Batch [100/469] - Loss_D: 0.2210, Loss_G: 2.8867
# Epoch [2/200], Batch [200/469] - Loss_D: 0.2164, Loss_G: 2.5772
# Epoch [2/200], Batch [300/469] - Loss_D: 0.2425, Loss_G: 2.9293
# Epoch [2/200], Batch [400/469] - Loss_D: 0.2375, Loss_G: 3.3215
# Epoch [3/200], Batch [0/469] - Loss_D: 0.2100, Loss_G: 3.0589
# Epoch [3/200], Batch [100/469] - Loss_D: 0.6083, Loss_G: 2.9122
# Epoch [3/200], Batch [200/469] - Loss_D: 0.3510, Loss_G: 2.2755
# Epoch [3/200], Batch [300/469] - Loss_D: 0.2365, Loss_G: 2.5360
# Epoch [3/200], Batch [400/469] - Loss_D: 0.8746, Loss_G: 2.3411
# Epoch [4/200], Batch [0/469] - Loss_D: 0.3323, Loss_G: 2.0933
# Epoch [4/200], Batch [100/469] - Loss_D: 0.1920, Loss_G: 2.5976
# Epoch [4/200], Batch [200/469] - Loss_D: 0.2404, Loss_G: 2.5360
# Epoch [4/200], Batch [300/469] - Loss_D: 1.0687, Loss_G: 0.6953
# Epoch [4/200], Batch [400/469] - Loss_D: 0.3114, Loss_G: 2.0741
# Epoch [5/200], Batch [0/469] - Loss_D: 0.4485, Loss_G: 2.0188
# Epoch [5/200], Batch [100/469] - Loss_D: 0.2583, Loss_G: 3.1052
# Epoch [5/200], Batch [200/469] - Loss_D: 0.2852, Loss_G: 2.9738
# Epoch [5/200], Batch [300/469] - Loss_D: 0.2371, Loss_G: 2.6743
# Epoch [5/200], Batch [400/469] - Loss_D: 0.3687, Loss_G: 1.5535
# Epoch [6/200], Batch [0/469] - Loss_D: 0.2207, Loss_G: 2.5527
# Epoch [6/200], Batch [100/469] - Loss_D: 0.1783, Loss_G: 3.9587
# Epoch [6/200], Batch [200/469] - Loss_D: 0.2731, Loss_G: 3.2785
# Epoch [6/200], Batch [300/469] - Loss_D: 0.4229, Loss_G: 5.2331
# Epoch [6/200], Batch [400/469] - Loss_D: 0.1403, Loss_G: 3.3551
# Epoch [7/200], Batch [0/469] - Loss_D: 0.3320, Loss_G: 4.3054
# Epoch [7/200], Batch [100/469] - Loss_D: 0.2835, Loss_G: 2.1857
# Epoch [7/200], Batch [200/469] - Loss_D: 0.2341, Loss_G: 3.8701
# Epoch [7/200], Batch [300/469] - Loss_D: 0.5149, Loss_G: 1.4265
# Epoch [7/200], Batch [400/469] - Loss_D: 0.3693, Loss_G: 1.3767
# Epoch [8/200], Batch [0/469] - Loss_D: 0.3310, Loss_G: 3.8781
# Epoch [8/200], Batch [100/469] - Loss_D: 0.3022, Loss_G: 1.9469
# Epoch [8/200], Batch [200/469] - Loss_D: 1.1975, Loss_G: 9.2192
# Epoch [8/200], Batch [300/469] - Loss_D: 0.1588, Loss_G: 3.4630
# Epoch [8/200], Batch [400/469] - Loss_D: 0.4419, Loss_G: 3.1958
# Epoch [9/200], Batch [0/469] - Loss_D: 0.1581, Loss_G: 3.5627
# Epoch [9/200], Batch [100/469] - Loss_D: 0.1940, Loss_G: 3.2289
# Epoch [9/200], Batch [200/469] - Loss_D: 0.2762, Loss_G: 1.8001
# Epoch [9/200], Batch [300/469] - Loss_D: 0.2028, Loss_G: 3.6809
# Epoch [9/200], Batch [400/469] - Loss_D: 0.1517, Loss_G: 4.4372
# Epoch [10/200], Batch [0/469] - Loss_D: 0.3673, Loss_G: 5.0973
# Epoch [10/200], Batch [100/469] - Loss_D: 0.1854, Loss_G: 3.6170
# Epoch [10/200], Batch [200/469] - Loss_D: 0.1123, Loss_G: 3.2116
# Epoch [10/200], Batch [300/469] - Loss_D: 0.5877, Loss_G: 1.7623
# Epoch [10/200], Batch [400/469] - Loss_D: 0.3373, Loss_G: 2.7706
# Epoch [11/200], Batch [0/469] - Loss_D: 0.1834, Loss_G: 3.4118
# Epoch [11/200], Batch [100/469] - Loss_D: 0.2141, Loss_G: 3.2201
# Epoch [11/200], Batch [200/469] - Loss_D: 0.2626, Loss_G: 2.8029
# Epoch [11/200], Batch [300/469] - Loss_D: 0.1104, Loss_G: 3.7596
# Epoch [11/200], Batch [400/469] - Loss_D: 0.1533, Loss_G: 3.1457
# Epoch [12/200], Batch [0/469] - Loss_D: 0.1168, Loss_G: 4.4097
# Epoch [12/200], Batch [100/469] - Loss_D: 0.1639, Loss_G: 3.4169
# Epoch [12/200], Batch [200/469] - Loss_D: 0.2682, Loss_G: 2.6898
# Epoch [12/200], Batch [300/469] - Loss_D: 0.0924, Loss_G: 4.0558
# Epoch [12/200], Batch [400/469] - Loss_D: 6.7824, Loss_G: 0.9437
# Epoch [13/200], Batch [0/469] - Loss_D: 0.4831, Loss_G: 3.6797
# Epoch [13/200], Batch [100/469] - Loss_D: 0.2291, Loss_G: 3.4225
# Epoch [13/200], Batch [200/469] - Loss_D: 0.2302, Loss_G: 4.9143
# Epoch [13/200], Batch [300/469] - Loss_D: 0.1575, Loss_G: 2.2049
# Epoch [13/200], Batch [400/469] - Loss_D: 0.1454, Loss_G: 3.3130
# Epoch [14/200], Batch [0/469] - Loss_D: 9.7681, Loss_G: 0.3459
# Epoch [14/200], Batch [100/469] - Loss_D: 0.3068, Loss_G: 2.2993
# Epoch [14/200], Batch [200/469] - Loss_D: 0.1782, Loss_G: 4.1807
# Epoch [14/200], Batch [300/469] - Loss_D: 0.6596, Loss_G: 1.8215
# Epoch [14/200], Batch [400/469] - Loss_D: 0.1853, Loss_G: 3.9224
# Epoch [15/200], Batch [0/469] - Loss_D: 0.3579, Loss_G: 2.3970
# Epoch [15/200], Batch [100/469] - Loss_D: 0.1408, Loss_G: 3.3798
# Epoch [15/200], Batch [200/469] - Loss_D: 0.1265, Loss_G: 4.1506
# Epoch [15/200], Batch [300/469] - Loss_D: 0.0698, Loss_G: 4.7718
# Epoch [15/200], Batch [400/469] - Loss_D: 0.1940, Loss_G: 3.9012
# Epoch [16/200], Batch [0/469] - Loss_D: 0.1420, Loss_G: 4.6793
# Epoch [16/200], Batch [100/469] - Loss_D: 0.1049, Loss_G: 3.5978
# Epoch [16/200], Batch [200/469] - Loss_D: 0.1473, Loss_G: 3.8973
# Epoch [16/200], Batch [300/469] - Loss_D: 0.6924, Loss_G: 1.4837
# Epoch [16/200], Batch [400/469] - Loss_D: 0.1501, Loss_G: 4.1401
# Epoch [17/200], Batch [0/469] - Loss_D: 0.1457, Loss_G: 2.9767
# Epoch [17/200], Batch [100/469] - Loss_D: 0.0906, Loss_G: 4.5663
# Epoch [17/200], Batch [200/469] - Loss_D: 0.1585, Loss_G: 3.1098
# Epoch [17/200], Batch [300/469] - Loss_D: 0.1695, Loss_G: 3.8586
# Epoch [17/200], Batch [400/469] - Loss_D: 0.3874, Loss_G: 3.0174
# Epoch [18/200], Batch [0/469] - Loss_D: 0.1466, Loss_G: 4.4381
# Epoch [18/200], Batch [100/469] - Loss_D: 0.1401, Loss_G: 5.2580
# Epoch [18/200], Batch [200/469] - Loss_D: 0.1294, Loss_G: 3.7679
# Epoch [18/200], Batch [300/469] - Loss_D: 0.3299, Loss_G: 4.1349
# Epoch [18/200], Batch [400/469] - Loss_D: 0.1168, Loss_G: 4.1005
# Epoch [19/200], Batch [0/469] - Loss_D: 0.1317, Loss_G: 3.7371
# Epoch [19/200], Batch [100/469] - Loss_D: 0.0296, Loss_G: 5.2619
# Epoch [19/200], Batch [200/469] - Loss_D: 0.0911, Loss_G: 4.6137
# Epoch [19/200], Batch [300/469] - Loss_D: 0.0952, Loss_G: 4.3084
# Epoch [19/200], Batch [400/469] - Loss_D: 0.1987, Loss_G: 5.0476
# Epoch [20/200], Batch [0/469] - Loss_D: 0.1944, Loss_G: 3.3393
# Epoch [20/200], Batch [100/469] - Loss_D: 0.3060, Loss_G: 2.9341
# Epoch [20/200], Batch [200/469] - Loss_D: 0.1280, Loss_G: 3.9430
# Epoch [20/200], Batch [300/469] - Loss_D: 0.3315, Loss_G: 5.1663
# Epoch [20/200], Batch [400/469] - Loss_D: 0.1307, Loss_G: 4.7370
# Epoch [21/200], Batch [0/469] - Loss_D: 0.0659, Loss_G: 4.7489
# Epoch [21/200], Batch [100/469] - Loss_D: 0.2296, Loss_G: 2.9406
# Epoch [21/200], Batch [200/469] - Loss_D: 0.0732, Loss_G: 4.2219
# Epoch [21/200], Batch [300/469] - Loss_D: 0.0726, Loss_G: 4.2119
# Epoch [21/200], Batch [400/469] - Loss_D: 0.1158, Loss_G: 5.0150
# Epoch [22/200], Batch [0/469] - Loss_D: 0.1656, Loss_G: 3.9841
# Epoch [22/200], Batch [100/469] - Loss_D: 0.0765, Loss_G: 3.5128
# Epoch [22/200], Batch [200/469] - Loss_D: 0.0576, Loss_G: 4.3134
# Epoch [22/200], Batch [300/469] - Loss_D: 0.9365, Loss_G: 1.1484
# Epoch [22/200], Batch [400/469] - Loss_D: 0.1255, Loss_G: 4.3324
# Epoch [23/200], Batch [0/469] - Loss_D: 0.0548, Loss_G: 4.6393
# Epoch [23/200], Batch [100/469] - Loss_D: 0.0587, Loss_G: 4.8158
# Epoch [23/200], Batch [200/469] - Loss_D: 0.0530, Loss_G: 5.0849
# Epoch [23/200], Batch [300/469] - Loss_D: 0.6138, Loss_G: 4.6264
# Epoch [23/200], Batch [400/469] - Loss_D: 0.1444, Loss_G: 5.2669
# Epoch [24/200], Batch [0/469] - Loss_D: 0.1057, Loss_G: 4.1981
# Epoch [24/200], Batch [100/469] - Loss_D: 0.0665, Loss_G: 4.8758
# Epoch [24/200], Batch [200/469] - Loss_D: 0.3826, Loss_G: 4.8603
# Epoch [24/200], Batch [300/469] - Loss_D: 0.0797, Loss_G: 3.6390
# Epoch [24/200], Batch [400/469] - Loss_D: 0.0423, Loss_G: 4.9606
# Epoch [25/200], Batch [0/469] - Loss_D: 0.0659, Loss_G: 4.2277
# Epoch [25/200], Batch [100/469] - Loss_D: 0.0382, Loss_G: 5.0807
# Epoch [25/200], Batch [200/469] - Loss_D: 0.1643, Loss_G: 3.4564
# Epoch [25/200], Batch [300/469] - Loss_D: 0.1213, Loss_G: 3.7136
# Epoch [25/200], Batch [400/469] - Loss_D: 0.0719, Loss_G: 4.3100
# Epoch [26/200], Batch [0/469] - Loss_D: 1.2315, Loss_G: 10.2931
# Epoch [26/200], Batch [100/469] - Loss_D: 0.0436, Loss_G: 4.6775
# Epoch [26/200], Batch [200/469] - Loss_D: 3.2103, Loss_G: 0.0417
# Epoch [26/200], Batch [300/469] - Loss_D: 0.1636, Loss_G: 4.1847
# Epoch [26/200], Batch [400/469] - Loss_D: 0.0638, Loss_G: 4.5276
# Epoch [27/200], Batch [0/469] - Loss_D: 0.0563, Loss_G: 4.5539
# Epoch [27/200], Batch [100/469] - Loss_D: 0.0530, Loss_G: 5.0484
# Epoch [27/200], Batch [200/469] - Loss_D: 0.0397, Loss_G: 5.5848
# Epoch [27/200], Batch [300/469] - Loss_D: 0.0963, Loss_G: 5.8665
# Epoch [27/200], Batch [400/469] - Loss_D: 0.0787, Loss_G: 5.6598
# Epoch [28/200], Batch [0/469] - Loss_D: 0.2376, Loss_G: 2.8579
# Epoch [28/200], Batch [100/469] - Loss_D: 0.0520, Loss_G: 4.6545
# Epoch [28/200], Batch [200/469] - Loss_D: 0.2544, Loss_G: 2.9585
# Epoch [28/200], Batch [300/469] - Loss_D: 0.0951, Loss_G: 4.0414
# Epoch [28/200], Batch [400/469] - Loss_D: 0.0400, Loss_G: 6.1053
# Epoch [29/200], Batch [0/469] - Loss_D: 0.0434, Loss_G: 4.9471
# Epoch [29/200], Batch [100/469] - Loss_D: 0.1532, Loss_G: 4.7438
# Epoch [29/200], Batch [200/469] - Loss_D: 0.0328, Loss_G: 5.0176
# Epoch [29/200], Batch [300/469] - Loss_D: 3.4774, Loss_G: 1.7940
# Epoch [29/200], Batch [400/469] - Loss_D: 0.3425, Loss_G: 2.2321
# Epoch [30/200], Batch [0/469] - Loss_D: 0.5231, Loss_G: 4.4213
# Epoch [30/200], Batch [100/469] - Loss_D: 0.3349, Loss_G: 2.6024
# Epoch [30/200], Batch [200/469] - Loss_D: 0.0438, Loss_G: 4.9182
# Epoch [30/200], Batch [300/469] - Loss_D: 0.2897, Loss_G: 3.6523
# Epoch [30/200], Batch [400/469] - Loss_D: 0.1028, Loss_G: 5.0406
# Epoch [31/200], Batch [0/469] - Loss_D: 0.0601, Loss_G: 4.8428
# Epoch [31/200], Batch [100/469] - Loss_D: 0.0584, Loss_G: 4.7505
# Epoch [31/200], Batch [200/469] - Loss_D: 0.0294, Loss_G: 5.2887
# Epoch [31/200], Batch [300/469] - Loss_D: 0.0405, Loss_G: 4.5966
# Epoch [31/200], Batch [400/469] - Loss_D: 0.3472, Loss_G: 4.1374
# Epoch [32/200], Batch [0/469] - Loss_D: 0.0774, Loss_G: 5.3226
# Epoch [32/200], Batch [100/469] - Loss_D: 0.0423, Loss_G: 6.2236
# Epoch [32/200], Batch [200/469] - Loss_D: 0.4170, Loss_G: 3.7318
# Epoch [32/200], Batch [300/469] - Loss_D: 0.1431, Loss_G: 4.6695
# Epoch [32/200], Batch [400/469] - Loss_D: 0.0382, Loss_G: 4.6407
# Epoch [33/200], Batch [0/469] - Loss_D: 0.0625, Loss_G: 6.9865
# Epoch [33/200], Batch [100/469] - Loss_D: 0.0824, Loss_G: 5.1538
# Epoch [33/200], Batch [200/469] - Loss_D: 0.0701, Loss_G: 4.8821
# Epoch [33/200], Batch [300/469] - Loss_D: 0.0480, Loss_G: 4.8709
# Epoch [33/200], Batch [400/469] - Loss_D: 0.0727, Loss_G: 5.0706
# Epoch [34/200], Batch [0/469] - Loss_D: 0.0566, Loss_G: 4.9260
# Epoch [34/200], Batch [100/469] - Loss_D: 0.0509, Loss_G: 4.4943
# Epoch [34/200], Batch [200/469] - Loss_D: 0.0407, Loss_G: 4.7922
# Epoch [34/200], Batch [300/469] - Loss_D: 1.5635, Loss_G: 7.1340
# Epoch [34/200], Batch [400/469] - Loss_D: 0.0443, Loss_G: 5.2850
# Epoch [35/200], Batch [0/469] - Loss_D: 0.0499, Loss_G: 4.4599
# Epoch [35/200], Batch [100/469] - Loss_D: 0.0386, Loss_G: 4.8745
# Epoch [35/200], Batch [200/469] - Loss_D: 4.7101, Loss_G: 5.3109
# Epoch [35/200], Batch [300/469] - Loss_D: 0.3693, Loss_G: 3.0423
# Epoch [35/200], Batch [400/469] - Loss_D: 0.0998, Loss_G: 4.6632
# Epoch [36/200], Batch [0/469] - Loss_D: 0.3052, Loss_G: 3.9112
# Epoch [36/200], Batch [100/469] - Loss_D: 0.1638, Loss_G: 5.3243
# Epoch [36/200], Batch [200/469] - Loss_D: 0.0384, Loss_G: 4.4711
# Epoch [36/200], Batch [300/469] - Loss_D: 0.0322, Loss_G: 5.0223
# Epoch [36/200], Batch [400/469] - Loss_D: 0.0476, Loss_G: 5.2795
# Epoch [37/200], Batch [0/469] - Loss_D: 0.0197, Loss_G: 5.3362
# Epoch [37/200], Batch [100/469] - Loss_D: 0.0474, Loss_G: 4.4611
# Epoch [37/200], Batch [200/469] - Loss_D: 0.0975, Loss_G: 4.3572
# Epoch [37/200], Batch [300/469] - Loss_D: 0.1599, Loss_G: 4.4044
# Epoch [37/200], Batch [400/469] - Loss_D: 0.0305, Loss_G: 5.4689
# Epoch [38/200], Batch [0/469] - Loss_D: 0.1381, Loss_G: 3.7614
# Epoch [38/200], Batch [100/469] - Loss_D: 0.0841, Loss_G: 4.9610
# Epoch [38/200], Batch [200/469] - Loss_D: 0.0344, Loss_G: 4.7707
# Epoch [38/200], Batch [300/469] - Loss_D: 0.1966, Loss_G: 3.0176
# Epoch [38/200], Batch [400/469] - Loss_D: 0.1497, Loss_G: 4.3737
# Epoch [39/200], Batch [0/469] - Loss_D: 0.1505, Loss_G: 4.8035
# Epoch [39/200], Batch [100/469] - Loss_D: 0.0449, Loss_G: 4.4594
# Epoch [39/200], Batch [200/469] - Loss_D: 0.0431, Loss_G: 4.9828
# Epoch [39/200], Batch [300/469] - Loss_D: 0.3888, Loss_G: 2.3098
# Epoch [39/200], Batch [400/469] - Loss_D: 0.0469, Loss_G: 4.5345
# Epoch [40/200], Batch [0/469] - Loss_D: 0.0435, Loss_G: 6.7731
# Epoch [40/200], Batch [100/469] - Loss_D: 0.0182, Loss_G: 5.7247
# Epoch [40/200], Batch [200/469] - Loss_D: 0.0413, Loss_G: 5.1884
# Epoch [40/200], Batch [300/469] - Loss_D: 0.0652, Loss_G: 5.5755
# Epoch [40/200], Batch [400/469] - Loss_D: 0.0209, Loss_G: 5.1208
# Epoch [41/200], Batch [0/469] - Loss_D: 0.0925, Loss_G: 5.6504
# Epoch [41/200], Batch [100/469] - Loss_D: 0.0907, Loss_G: 3.6849
# Epoch [41/200], Batch [200/469] - Loss_D: 0.0666, Loss_G: 5.3757
# Epoch [41/200], Batch [300/469] - Loss_D: 0.0135, Loss_G: 6.3207
# Epoch [41/200], Batch [400/469] - Loss_D: 0.0143, Loss_G: 6.1389
# Epoch [42/200], Batch [0/469] - Loss_D: 0.4292, Loss_G: 1.9915
# Epoch [42/200], Batch [100/469] - Loss_D: 0.2228, Loss_G: 4.4764
# Epoch [42/200], Batch [200/469] - Loss_D: 0.0519, Loss_G: 4.5007
# Epoch [42/200], Batch [300/469] - Loss_D: 0.0385, Loss_G: 4.7701
# Epoch [42/200], Batch [400/469] - Loss_D: 0.0395, Loss_G: 5.1890
# Epoch [43/200], Batch [0/469] - Loss_D: 0.1121, Loss_G: 4.1272
# Epoch [43/200], Batch [100/469] - Loss_D: 0.0901, Loss_G: 3.8480
# Epoch [43/200], Batch [200/469] - Loss_D: 0.0757, Loss_G: 3.9628
# Epoch [43/200], Batch [300/469] - Loss_D: 0.0205, Loss_G: 6.2254
# Epoch [43/200], Batch [400/469] - Loss_D: 0.1068, Loss_G: 4.2601
# Epoch [44/200], Batch [0/469] - Loss_D: 0.0226, Loss_G: 5.9557
# Epoch [44/200], Batch [100/469] - Loss_D: 0.0490, Loss_G: 5.0025
# Epoch [44/200], Batch [200/469] - Loss_D: 0.0336, Loss_G: 5.3058
# Epoch [44/200], Batch [300/469] - Loss_D: 0.0272, Loss_G: 5.4526
# Epoch [44/200], Batch [400/469] - Loss_D: 0.3606, Loss_G: 2.9060
# Epoch [45/200], Batch [0/469] - Loss_D: 1.1546, Loss_G: 5.1214
# Epoch [45/200], Batch [100/469] - Loss_D: 0.6927, Loss_G: 2.6295
# Epoch [45/200], Batch [200/469] - Loss_D: 0.1557, Loss_G: 3.1427
# Epoch [45/200], Batch [300/469] - Loss_D: 0.0787, Loss_G: 3.6278
# Epoch [45/200], Batch [400/469] - Loss_D: 0.0513, Loss_G: 4.7655
# Epoch [46/200], Batch [0/469] - Loss_D: 0.0354, Loss_G: 5.0197
# Epoch [46/200], Batch [100/469] - Loss_D: 0.0308, Loss_G: 4.9491
# Epoch [46/200], Batch [200/469] - Loss_D: 0.1166, Loss_G: 4.9212
# Epoch [46/200], Batch [300/469] - Loss_D: 0.1154, Loss_G: 4.1712
# Epoch [46/200], Batch [400/469] - Loss_D: 0.0847, Loss_G: 5.3277
# Epoch [47/200], Batch [0/469] - Loss_D: 0.0471, Loss_G: 5.4431
# Epoch [47/200], Batch [100/469] - Loss_D: 0.0285, Loss_G: 5.8311
# Epoch [47/200], Batch [200/469] - Loss_D: 0.0807, Loss_G: 4.2278
# Epoch [47/200], Batch [300/469] - Loss_D: 0.0130, Loss_G: 5.8761
# Epoch [47/200], Batch [400/469] - Loss_D: 0.0244, Loss_G: 5.7499
# Epoch [48/200], Batch [0/469] - Loss_D: 0.0135, Loss_G: 6.9825
# Epoch [48/200], Batch [100/469] - Loss_D: 0.1531, Loss_G: 4.9343
# Epoch [48/200], Batch [200/469] - Loss_D: 0.1163, Loss_G: 3.5537
# Epoch [48/200], Batch [300/469] - Loss_D: 0.0219, Loss_G: 6.0091
# Epoch [48/200], Batch [400/469] - Loss_D: 0.0845, Loss_G: 5.8843
# Epoch [49/200], Batch [0/469] - Loss_D: 0.0190, Loss_G: 5.6350
# Epoch [49/200], Batch [100/469] - Loss_D: 0.0168, Loss_G: 5.9899
# Epoch [49/200], Batch [200/469] - Loss_D: 0.2962, Loss_G: 3.7643
# Epoch [49/200], Batch [300/469] - Loss_D: 0.0347, Loss_G: 5.0414
# Epoch [49/200], Batch [400/469] - Loss_D: 0.0408, Loss_G: 4.5968
# Epoch [50/200], Batch [0/469] - Loss_D: 0.0282, Loss_G: 5.2170
# Epoch [50/200], Batch [100/469] - Loss_D: 0.0217, Loss_G: 6.1269
# Epoch [50/200], Batch [200/469] - Loss_D: 0.0783, Loss_G: 5.6322
# Epoch [50/200], Batch [300/469] - Loss_D: 0.1834, Loss_G: 3.5168
# Epoch [50/200], Batch [400/469] - Loss_D: 0.0530, Loss_G: 5.1408
# Epoch [51/200], Batch [0/469] - Loss_D: 0.0317, Loss_G: 5.1349
# Epoch [51/200], Batch [100/469] - Loss_D: 0.0580, Loss_G: 5.4472
# Epoch [51/200], Batch [200/469] - Loss_D: 0.0252, Loss_G: 6.2644
# Epoch [51/200], Batch [300/469] - Loss_D: 6.4744, Loss_G: 4.2335
# Epoch [51/200], Batch [400/469] - Loss_D: 0.0924, Loss_G: 4.4667
# Epoch [52/200], Batch [0/469] - Loss_D: 0.1357, Loss_G: 2.8766
# Epoch [52/200], Batch [100/469] - Loss_D: 0.0239, Loss_G: 5.8467
# Epoch [52/200], Batch [200/469] - Loss_D: 0.0460, Loss_G: 5.2415
# Epoch [52/200], Batch [300/469] - Loss_D: 0.0186, Loss_G: 6.7466
# Epoch [52/200], Batch [400/469] - Loss_D: 0.0457, Loss_G: 5.4961
# Epoch [53/200], Batch [0/469] - Loss_D: 0.0255, Loss_G: 6.6343
# Epoch [53/200], Batch [100/469] - Loss_D: 0.0171, Loss_G: 5.3901
# Epoch [53/200], Batch [200/469] - Loss_D: 0.0543, Loss_G: 5.3161
# Epoch [53/200], Batch [300/469] - Loss_D: 0.0350, Loss_G: 6.0502
# Epoch [53/200], Batch [400/469] - Loss_D: 0.3550, Loss_G: 5.3854
# Epoch [54/200], Batch [0/469] - Loss_D: 0.1692, Loss_G: 3.2560
# Epoch [54/200], Batch [100/469] - Loss_D: 0.2132, Loss_G: 6.3366
# Epoch [54/200], Batch [200/469] - Loss_D: 0.0384, Loss_G: 5.4699
# Epoch [54/200], Batch [300/469] - Loss_D: 0.0208, Loss_G: 6.3073
# Epoch [54/200], Batch [400/469] - Loss_D: 0.0542, Loss_G: 5.0807
# Epoch [55/200], Batch [0/469] - Loss_D: 0.0478, Loss_G: 4.5244
# Epoch [55/200], Batch [100/469] - Loss_D: 0.0250, Loss_G: 5.3665
# Epoch [55/200], Batch [200/469] - Loss_D: 0.0178, Loss_G: 6.4439
# Epoch [55/200], Batch [300/469] - Loss_D: 0.0197, Loss_G: 5.9862
# Epoch [55/200], Batch [400/469] - Loss_D: 0.0541, Loss_G: 5.3509
# Epoch [56/200], Batch [0/469] - Loss_D: 0.0244, Loss_G: 5.6789
# Epoch [56/200], Batch [100/469] - Loss_D: 0.0147, Loss_G: 6.1463
# Epoch [56/200], Batch [200/469] - Loss_D: 0.5129, Loss_G: 3.9165
# Epoch [56/200], Batch [300/469] - Loss_D: 0.0257, Loss_G: 5.5168
# Epoch [56/200], Batch [400/469] - Loss_D: 0.0217, Loss_G: 5.5547
# Epoch [57/200], Batch [0/469] - Loss_D: 0.0352, Loss_G: 5.5090
# Epoch [57/200], Batch [100/469] - Loss_D: 0.3858, Loss_G: 4.9803
# Epoch [57/200], Batch [200/469] - Loss_D: 0.2471, Loss_G: 2.9762
# Epoch [57/200], Batch [300/469] - Loss_D: 0.0554, Loss_G: 5.4289
# Epoch [57/200], Batch [400/469] - Loss_D: 0.0387, Loss_G: 5.2053
# Epoch [58/200], Batch [0/469] - Loss_D: 0.1851, Loss_G: 4.5790
# Epoch [58/200], Batch [100/469] - Loss_D: 0.0894, Loss_G: 4.9338
# Epoch [58/200], Batch [200/469] - Loss_D: 0.0154, Loss_G: 6.5461
# Epoch [58/200], Batch [300/469] - Loss_D: 0.0087, Loss_G: 6.2777
# Epoch [58/200], Batch [400/469] - Loss_D: 0.0144, Loss_G: 6.5084
# Epoch [59/200], Batch [0/469] - Loss_D: 1.0282, Loss_G: 1.0125
# Epoch [59/200], Batch [100/469] - Loss_D: 0.4628, Loss_G: 3.0221
# Epoch [59/200], Batch [200/469] - Loss_D: 0.4214, Loss_G: 4.3909
# Epoch [59/200], Batch [300/469] - Loss_D: 0.2574, Loss_G: 3.5389
# Epoch [59/200], Batch [400/469] - Loss_D: 0.0398, Loss_G: 5.2333
# Epoch [60/200], Batch [0/469] - Loss_D: 0.0366, Loss_G: 5.6643
# Epoch [60/200], Batch [100/469] - Loss_D: 0.0452, Loss_G: 4.5530
# Epoch [60/200], Batch [200/469] - Loss_D: 0.0394, Loss_G: 5.1651
# Epoch [60/200], Batch [300/469] - Loss_D: 0.0244, Loss_G: 5.8532
# Epoch [60/200], Batch [400/469] - Loss_D: 0.0135, Loss_G: 6.0059
# Epoch [61/200], Batch [0/469] - Loss_D: 0.0146, Loss_G: 7.0478
# Epoch [61/200], Batch [100/469] - Loss_D: 0.1698, Loss_G: 3.0469
# Epoch [61/200], Batch [200/469] - Loss_D: 0.1285, Loss_G: 6.1227
# Epoch [61/200], Batch [300/469] - Loss_D: 0.0468, Loss_G: 5.5109
# Epoch [61/200], Batch [400/469] - Loss_D: 0.0181, Loss_G: 6.3382
# Epoch [62/200], Batch [0/469] - Loss_D: 0.0201, Loss_G: 6.0904
# Epoch [62/200], Batch [100/469] - Loss_D: 0.3242, Loss_G: 4.2083
# Epoch [62/200], Batch [200/469] - Loss_D: 0.0421, Loss_G: 5.4875
# Epoch [62/200], Batch [300/469] - Loss_D: 0.0472, Loss_G: 6.3497
# Epoch [62/200], Batch [400/469] - Loss_D: 0.0117, Loss_G: 5.8437
# Epoch [63/200], Batch [0/469] - Loss_D: 0.0169, Loss_G: 6.2976
# Epoch [63/200], Batch [100/469] - Loss_D: 0.0561, Loss_G: 6.4757
# Epoch [63/200], Batch [200/469] - Loss_D: 0.0206, Loss_G: 5.7877
# Epoch [63/200], Batch [300/469] - Loss_D: 0.0820, Loss_G: 6.3217
# Epoch [63/200], Batch [400/469] - Loss_D: 0.0249, Loss_G: 5.6195
# Epoch [64/200], Batch [0/469] - Loss_D: 0.9564, Loss_G: 4.5249
# Epoch [64/200], Batch [100/469] - Loss_D: 0.1450, Loss_G: 4.8361
# Epoch [64/200], Batch [200/469] - Loss_D: 0.0331, Loss_G: 5.9349
# Epoch [64/200], Batch [300/469] - Loss_D: 0.0639, Loss_G: 4.3788
# Epoch [64/200], Batch [400/469] - Loss_D: 0.0138, Loss_G: 6.0675
# Epoch [65/200], Batch [0/469] - Loss_D: 0.0865, Loss_G: 5.8111
# Epoch [65/200], Batch [100/469] - Loss_D: 0.2318, Loss_G: 2.5881
# Epoch [65/200], Batch [200/469] - Loss_D: 0.0276, Loss_G: 5.6949
# Epoch [65/200], Batch [300/469] - Loss_D: 0.0245, Loss_G: 5.8341
# Epoch [65/200], Batch [400/469] - Loss_D: 0.0463, Loss_G: 4.5729
# Epoch [66/200], Batch [0/469] - Loss_D: 0.0381, Loss_G: 5.2294
# Epoch [66/200], Batch [100/469] - Loss_D: 0.0185, Loss_G: 5.8863
# Epoch [66/200], Batch [200/469] - Loss_D: 0.1074, Loss_G: 4.5836
# Epoch [66/200], Batch [300/469] - Loss_D: 0.0292, Loss_G: 6.0162
# Epoch [66/200], Batch [400/469] - Loss_D: 0.0442, Loss_G: 5.1180
# Epoch [67/200], Batch [0/469] - Loss_D: 0.0496, Loss_G: 5.8416
# Epoch [67/200], Batch [100/469] - Loss_D: 0.0328, Loss_G: 5.5346
# Epoch [67/200], Batch [200/469] - Loss_D: 0.0188, Loss_G: 5.7993
# Epoch [67/200], Batch [300/469] - Loss_D: 0.1141, Loss_G: 5.1997
# Epoch [67/200], Batch [400/469] - Loss_D: 0.0190, Loss_G: 5.4657
# Epoch [68/200], Batch [0/469] - Loss_D: 0.0110, Loss_G: 6.3164
# Epoch [68/200], Batch [100/469] - Loss_D: 0.0245, Loss_G: 5.5854
# Epoch [68/200], Batch [200/469] - Loss_D: 0.0457, Loss_G: 5.7608
# Epoch [68/200], Batch [300/469] - Loss_D: 0.0521, Loss_G: 5.9931
# Epoch [68/200], Batch [400/469] - Loss_D: 0.0246, Loss_G: 6.4639
# Epoch [69/200], Batch [0/469] - Loss_D: 0.1314, Loss_G: 7.3031
# Epoch [69/200], Batch [100/469] - Loss_D: 0.0580, Loss_G: 5.5653
# Epoch [69/200], Batch [200/469] - Loss_D: 0.4644, Loss_G: 1.5829
# Epoch [69/200], Batch [300/469] - Loss_D: 0.0402, Loss_G: 5.0309
# Epoch [69/200], Batch [400/469] - Loss_D: 0.2436, Loss_G: 1.8071
# Epoch [70/200], Batch [0/469] - Loss_D: 0.3458, Loss_G: 4.9235
# Epoch [70/200], Batch [100/469] - Loss_D: 0.0243, Loss_G: 5.6159
# Epoch [70/200], Batch [200/469] - Loss_D: 0.0263, Loss_G: 5.3456
# Epoch [70/200], Batch [300/469] - Loss_D: 0.0176, Loss_G: 5.7701
# Epoch [70/200], Batch [400/469] - Loss_D: 0.0026, Loss_G: 7.8782
# Epoch [71/200], Batch [0/469] - Loss_D: 0.0551, Loss_G: 5.3417
# Epoch [71/200], Batch [100/469] - Loss_D: 0.0202, Loss_G: 5.3287
# Epoch [71/200], Batch [200/469] - Loss_D: 0.0128, Loss_G: 6.8739
# Epoch [71/200], Batch [300/469] - Loss_D: 0.7512, Loss_G: 0.8478
# Epoch [71/200], Batch [400/469] - Loss_D: 0.9683, Loss_G: 6.8718
# Epoch [72/200], Batch [0/469] - Loss_D: 0.0261, Loss_G: 5.0470
# Epoch [72/200], Batch [100/469] - Loss_D: 0.0146, Loss_G: 6.9202
# Epoch [72/200], Batch [200/469] - Loss_D: 0.0214, Loss_G: 5.8717
# Epoch [72/200], Batch [300/469] - Loss_D: 0.0519, Loss_G: 4.1865
# Epoch [72/200], Batch [400/469] - Loss_D: 0.0240, Loss_G: 5.6562
# Epoch [73/200], Batch [0/469] - Loss_D: 0.0201, Loss_G: 5.9654
# Epoch [73/200], Batch [100/469] - Loss_D: 0.1949, Loss_G: 3.7921
# Epoch [73/200], Batch [200/469] - Loss_D: 0.0369, Loss_G: 5.7421
# Epoch [73/200], Batch [300/469] - Loss_D: 0.0996, Loss_G: 4.1976
# Epoch [73/200], Batch [400/469] - Loss_D: 0.0765, Loss_G: 3.7436
# Epoch [74/200], Batch [0/469] - Loss_D: 0.0963, Loss_G: 4.3261
# Epoch [74/200], Batch [100/469] - Loss_D: 0.0140, Loss_G: 5.8431
# Epoch [74/200], Batch [200/469] - Loss_D: 0.0464, Loss_G: 5.8425
# Epoch [74/200], Batch [300/469] - Loss_D: 0.0417, Loss_G: 6.2026
# Epoch [74/200], Batch [400/469] - Loss_D: 0.3181, Loss_G: 3.7644
# Epoch [75/200], Batch [0/469] - Loss_D: 0.0058, Loss_G: 7.3838
# Epoch [75/200], Batch [100/469] - Loss_D: 0.2108, Loss_G: 2.1812
# Epoch [75/200], Batch [200/469] - Loss_D: 0.0130, Loss_G: 6.3890
# Epoch [75/200], Batch [300/469] - Loss_D: 0.0109, Loss_G: 6.4912
# Epoch [75/200], Batch [400/469] - Loss_D: 0.0674, Loss_G: 4.7430
# Epoch [76/200], Batch [0/469] - Loss_D: 0.0404, Loss_G: 5.8572
# Epoch [76/200], Batch [100/469] - Loss_D: 0.0235, Loss_G: 5.7595
# Epoch [76/200], Batch [200/469] - Loss_D: 0.0692, Loss_G: 4.3610
# Epoch [76/200], Batch [300/469] - Loss_D: 0.1593, Loss_G: 3.8863
# Epoch [76/200], Batch [400/469] - Loss_D: 0.0228, Loss_G: 6.0903
# Epoch [77/200], Batch [0/469] - Loss_D: 0.0224, Loss_G: 6.5032
# Epoch [77/200], Batch [100/469] - Loss_D: 0.0876, Loss_G: 5.2971
# Epoch [77/200], Batch [200/469] - Loss_D: 0.0158, Loss_G: 5.6907
# Epoch [77/200], Batch [300/469] - Loss_D: 0.0223, Loss_G: 6.0440
# Epoch [77/200], Batch [400/469] - Loss_D: 0.0587, Loss_G: 5.1395
# Epoch [78/200], Batch [0/469] - Loss_D: 0.0342, Loss_G: 5.1387
# Epoch [78/200], Batch [100/469] - Loss_D: 0.0304, Loss_G: 5.9754
# Epoch [78/200], Batch [200/469] - Loss_D: 0.0193, Loss_G: 6.8496
# Epoch [78/200], Batch [300/469] - Loss_D: 0.2776, Loss_G: 9.1646
# Epoch [78/200], Batch [400/469] - Loss_D: 0.0939, Loss_G: 4.3364
# Epoch [79/200], Batch [0/469] - Loss_D: 0.0910, Loss_G: 4.4214
# Epoch [79/200], Batch [100/469] - Loss_D: 0.0662, Loss_G: 4.3055
# Epoch [79/200], Batch [200/469] - Loss_D: 0.0284, Loss_G: 5.2613
# Epoch [79/200], Batch [300/469] - Loss_D: 0.0427, Loss_G: 5.2742
# Epoch [79/200], Batch [400/469] - Loss_D: 0.0254, Loss_G: 5.8487
# Epoch [80/200], Batch [0/469] - Loss_D: 0.0061, Loss_G: 6.8283
# Epoch [80/200], Batch [100/469] - Loss_D: 0.0357, Loss_G: 4.7234
# Epoch [80/200], Batch [200/469] - Loss_D: 0.0186, Loss_G: 7.7051
# Epoch [80/200], Batch [300/469] - Loss_D: 0.0403, Loss_G: 6.1150
# Epoch [80/200], Batch [400/469] - Loss_D: 0.0178, Loss_G: 6.1146
# Epoch [81/200], Batch [0/469] - Loss_D: 0.0058, Loss_G: 6.9341
# Epoch [81/200], Batch [100/469] - Loss_D: 0.0946, Loss_G: 4.7433
# Epoch [81/200], Batch [200/469] - Loss_D: 0.0620, Loss_G: 4.8953
# Epoch [81/200], Batch [300/469] - Loss_D: 0.0219, Loss_G: 7.0804
# Epoch [81/200], Batch [400/469] - Loss_D: 0.0177, Loss_G: 5.1661
# Epoch [82/200], Batch [0/469] - Loss_D: 0.0207, Loss_G: 6.1230
# Epoch [82/200], Batch [100/469] - Loss_D: 0.0084, Loss_G: 6.2020
# Epoch [82/200], Batch [200/469] - Loss_D: 0.0154, Loss_G: 7.0152
# Epoch [82/200], Batch [300/469] - Loss_D: 0.0109, Loss_G: 6.5617
# Epoch [82/200], Batch [400/469] - Loss_D: 0.0085, Loss_G: 6.4702
# Epoch [83/200], Batch [0/469] - Loss_D: 0.3479, Loss_G: 3.6470
# Epoch [83/200], Batch [100/469] - Loss_D: 0.4224, Loss_G: 8.1569
# Epoch [83/200], Batch [200/469] - Loss_D: 0.0071, Loss_G: 6.8142
# Epoch [83/200], Batch [300/469] - Loss_D: 0.1479, Loss_G: 3.2125
# Epoch [83/200], Batch [400/469] - Loss_D: 0.0936, Loss_G: 5.4719
# Epoch [84/200], Batch [0/469] - Loss_D: 0.0231, Loss_G: 5.9157
# Epoch [84/200], Batch [100/469] - Loss_D: 0.2187, Loss_G: 3.1533
# Epoch [84/200], Batch [200/469] - Loss_D: 0.0236, Loss_G: 5.9767
# Epoch [84/200], Batch [300/469] - Loss_D: 0.0469, Loss_G: 5.5117
# Epoch [84/200], Batch [400/469] - Loss_D: 0.0609, Loss_G: 4.8803
# Epoch [85/200], Batch [0/469] - Loss_D: 0.3026, Loss_G: 2.5722
# Epoch [85/200], Batch [100/469] - Loss_D: 0.0642, Loss_G: 4.8743
# Epoch [85/200], Batch [200/469] - Loss_D: 0.0072, Loss_G: 6.6146
# Epoch [85/200], Batch [300/469] - Loss_D: 0.0177, Loss_G: 6.1220
# Epoch [85/200], Batch [400/469] - Loss_D: 0.0545, Loss_G: 6.1293
# Epoch [86/200], Batch [0/469] - Loss_D: 0.0152, Loss_G: 6.7457
# Epoch [86/200], Batch [100/469] - Loss_D: 0.0363, Loss_G: 5.9099
# Epoch [86/200], Batch [200/469] - Loss_D: 0.0088, Loss_G: 6.1230
# Epoch [86/200], Batch [300/469] - Loss_D: 0.0171, Loss_G: 6.2114
# Epoch [86/200], Batch [400/469] - Loss_D: 0.0209, Loss_G: 5.4078
# Epoch [87/200], Batch [0/469] - Loss_D: 0.0923, Loss_G: 5.1724
# Epoch [87/200], Batch [100/469] - Loss_D: 0.0453, Loss_G: 4.4848
# Epoch [87/200], Batch [200/469] - Loss_D: 0.0187, Loss_G: 6.8207
# Epoch [87/200], Batch [300/469] - Loss_D: 0.0092, Loss_G: 6.3610
# Epoch [87/200], Batch [400/469] - Loss_D: 0.0119, Loss_G: 7.0858
# Epoch [88/200], Batch [0/469] - Loss_D: 0.0082, Loss_G: 8.3458
# Epoch [88/200], Batch [100/469] - Loss_D: 0.0645, Loss_G: 4.1047
# Epoch [88/200], Batch [200/469] - Loss_D: 0.0641, Loss_G: 5.1100
# Epoch [88/200], Batch [300/469] - Loss_D: 0.0223, Loss_G: 6.0108
# Epoch [88/200], Batch [400/469] - Loss_D: 0.0139, Loss_G: 6.3975
# Epoch [89/200], Batch [0/469] - Loss_D: 0.0301, Loss_G: 5.0737
# Epoch [89/200], Batch [100/469] - Loss_D: 0.1956, Loss_G: 3.7119
# Epoch [89/200], Batch [200/469] - Loss_D: 0.3151, Loss_G: 4.8058
# Epoch [89/200], Batch [300/469] - Loss_D: 0.1248, Loss_G: 3.3260
# Epoch [89/200], Batch [400/469] - Loss_D: 0.1520, Loss_G: 4.8061
# Epoch [90/200], Batch [0/469] - Loss_D: 0.0770, Loss_G: 4.6845
# Epoch [90/200], Batch [100/469] - Loss_D: 0.0427, Loss_G: 6.2974
# Epoch [90/200], Batch [200/469] - Loss_D: 0.0353, Loss_G: 5.3801
# Epoch [90/200], Batch [300/469] - Loss_D: 0.1939, Loss_G: 2.9956
# Epoch [90/200], Batch [400/469] - Loss_D: 0.0338, Loss_G: 5.7025
# Epoch [91/200], Batch [0/469] - Loss_D: 0.0266, Loss_G: 6.6886
# Epoch [91/200], Batch [100/469] - Loss_D: 0.0159, Loss_G: 6.1258
# Epoch [91/200], Batch [200/469] - Loss_D: 0.0273, Loss_G: 5.5168
# Epoch [91/200], Batch [300/469] - Loss_D: 0.0094, Loss_G: 6.2407
# Epoch [91/200], Batch [400/469] - Loss_D: 0.0234, Loss_G: 5.9049
# Epoch [92/200], Batch [0/469] - Loss_D: 3.0093, Loss_G: 0.0971
# Epoch [92/200], Batch [100/469] - Loss_D: 0.1531, Loss_G: 2.8135
# Epoch [92/200], Batch [200/469] - Loss_D: 0.0690, Loss_G: 5.8543
# Epoch [92/200], Batch [300/469] - Loss_D: 0.0245, Loss_G: 5.5778
# Epoch [92/200], Batch [400/469] - Loss_D: 0.0127, Loss_G: 6.0133
# Epoch [93/200], Batch [0/469] - Loss_D: 0.0121, Loss_G: 6.4382
# Epoch [93/200], Batch [100/469] - Loss_D: 0.0071, Loss_G: 6.5274
# Epoch [93/200], Batch [200/469] - Loss_D: 0.0361, Loss_G: 5.6979
# Epoch [93/200], Batch [300/469] - Loss_D: 0.0216, Loss_G: 6.1902
# Epoch [93/200], Batch [400/469] - Loss_D: 0.7586, Loss_G: 3.0347
# Epoch [94/200], Batch [0/469] - Loss_D: 0.0457, Loss_G: 5.4027
# Epoch [94/200], Batch [100/469] - Loss_D: 0.0123, Loss_G: 6.3304
# Epoch [94/200], Batch [200/469] - Loss_D: 0.0235, Loss_G: 6.9020
# Epoch [94/200], Batch [300/469] - Loss_D: 0.0470, Loss_G: 5.5347
# Epoch [94/200], Batch [400/469] - Loss_D: 0.0319, Loss_G: 5.7951
# Epoch [95/200], Batch [0/469] - Loss_D: 0.0564, Loss_G: 5.9776
# Epoch [95/200], Batch [100/469] - Loss_D: 0.0247, Loss_G: 6.5611
# Epoch [95/200], Batch [200/469] - Loss_D: 0.0164, Loss_G: 6.1503
# Epoch [95/200], Batch [300/469] - Loss_D: 0.0068, Loss_G: 6.7918
# Epoch [95/200], Batch [400/469] - Loss_D: 0.0180, Loss_G: 5.9757
# Epoch [96/200], Batch [0/469] - Loss_D: 0.0328, Loss_G: 7.9761
# Epoch [96/200], Batch [100/469] - Loss_D: 0.1075, Loss_G: 4.1313
# Epoch [96/200], Batch [200/469] - Loss_D: 0.0498, Loss_G: 4.5618
# Epoch [96/200], Batch [300/469] - Loss_D: 0.0159, Loss_G: 5.5603
# Epoch [96/200], Batch [400/469] - Loss_D: 0.0262, Loss_G: 5.7494
# Epoch [97/200], Batch [0/469] - Loss_D: 0.0118, Loss_G: 6.1120
# Epoch [97/200], Batch [100/469] - Loss_D: 0.0146, Loss_G: 6.1690
# Epoch [97/200], Batch [200/469] - Loss_D: 0.1722, Loss_G: 3.7265
# Epoch [97/200], Batch [300/469] - Loss_D: 0.0126, Loss_G: 7.0182
# Epoch [97/200], Batch [400/469] - Loss_D: 0.0335, Loss_G: 5.1489
# Epoch [98/200], Batch [0/469] - Loss_D: 0.0346, Loss_G: 6.7007
# Epoch [98/200], Batch [100/469] - Loss_D: 0.0055, Loss_G: 7.0256
# Epoch [98/200], Batch [200/469] - Loss_D: 0.0088, Loss_G: 6.5072
# Epoch [98/200], Batch [300/469] - Loss_D: 0.0162, Loss_G: 5.7243
# Epoch [98/200], Batch [400/469] - Loss_D: 0.0213, Loss_G: 5.8586
# Epoch [99/200], Batch [0/469] - Loss_D: 0.3446, Loss_G: 3.4996
# Epoch [99/200], Batch [100/469] - Loss_D: 0.0448, Loss_G: 5.2638
# Epoch [99/200], Batch [200/469] - Loss_D: 0.0308, Loss_G: 5.5030
# Epoch [99/200], Batch [300/469] - Loss_D: 0.6561, Loss_G: 1.5688
# Epoch [99/200], Batch [400/469] - Loss_D: 0.1549, Loss_G: 4.0098
# Epoch [100/200], Batch [0/469] - Loss_D: 0.1265, Loss_G: 5.8339
# Epoch [100/200], Batch [100/469] - Loss_D: 0.0273, Loss_G: 5.6607
# Epoch [100/200], Batch [200/469] - Loss_D: 0.0154, Loss_G: 6.1504
# Epoch [100/200], Batch [300/469] - Loss_D: 0.0088, Loss_G: 7.7782
# Epoch [100/200], Batch [400/469] - Loss_D: 0.0450, Loss_G: 4.6746
# Epoch [101/200], Batch [0/469] - Loss_D: 0.0651, Loss_G: 5.3035
# Epoch [101/200], Batch [100/469] - Loss_D: 0.0069, Loss_G: 7.2623
# Epoch [101/200], Batch [200/469] - Loss_D: 0.0075, Loss_G: 7.0794
# Epoch [101/200], Batch [300/469] - Loss_D: 0.1373, Loss_G: 4.4982
# Epoch [101/200], Batch [400/469] - Loss_D: 0.0244, Loss_G: 6.8195
# Epoch [102/200], Batch [0/469] - Loss_D: 0.0280, Loss_G: 5.8792
# Epoch [102/200], Batch [100/469] - Loss_D: 0.0249, Loss_G: 5.7354
# Epoch [102/200], Batch [200/469] - Loss_D: 0.0066, Loss_G: 6.9318
# Epoch [102/200], Batch [300/469] - Loss_D: 0.0404, Loss_G: 5.4385
# Epoch [102/200], Batch [400/469] - Loss_D: 0.0117, Loss_G: 6.5316
# Epoch [103/200], Batch [0/469] - Loss_D: 0.0142, Loss_G: 6.3812
# Epoch [103/200], Batch [100/469] - Loss_D: 0.0346, Loss_G: 6.0723
# Epoch [103/200], Batch [200/469] - Loss_D: 0.0043, Loss_G: 7.9053
# Epoch [103/200], Batch [300/469] - Loss_D: 0.3158, Loss_G: 2.1254
# Epoch [103/200], Batch [400/469] - Loss_D: 0.1304, Loss_G: 3.7117
# Epoch [104/200], Batch [0/469] - Loss_D: 0.0306, Loss_G: 6.3288
# Epoch [104/200], Batch [100/469] - Loss_D: 0.0131, Loss_G: 5.7206
# Epoch [104/200], Batch [200/469] - Loss_D: 0.0290, Loss_G: 5.6996
# Epoch [104/200], Batch [300/469] - Loss_D: 0.0053, Loss_G: 8.0582
# Epoch [104/200], Batch [400/469] - Loss_D: 0.0392, Loss_G: 6.3562
# Epoch [105/200], Batch [0/469] - Loss_D: 0.0182, Loss_G: 5.9240
# Epoch [105/200], Batch [100/469] - Loss_D: 0.0536, Loss_G: 4.9126
# Epoch [105/200], Batch [200/469] - Loss_D: 0.0030, Loss_G: 7.8937
# Epoch [105/200], Batch [300/469] - Loss_D: 0.4505, Loss_G: 1.7571
# Epoch [105/200], Batch [400/469] - Loss_D: 0.1290, Loss_G: 4.7374
# Epoch [106/200], Batch [0/469] - Loss_D: 0.1125, Loss_G: 4.1492
# Epoch [106/200], Batch [100/469] - Loss_D: 0.1361, Loss_G: 4.3336
# Epoch [106/200], Batch [200/469] - Loss_D: 0.0560, Loss_G: 4.8904
# Epoch [106/200], Batch [300/469] - Loss_D: 0.0170, Loss_G: 5.4619
# Epoch [106/200], Batch [400/469] - Loss_D: 0.0212, Loss_G: 5.6646
# Epoch [107/200], Batch [0/469] - Loss_D: 0.0053, Loss_G: 6.6061
# Epoch [107/200], Batch [100/469] - Loss_D: 0.0248, Loss_G: 6.3640
# Epoch [107/200], Batch [200/469] - Loss_D: 0.0387, Loss_G: 6.3944
# Epoch [107/200], Batch [300/469] - Loss_D: 0.1595, Loss_G: 5.8352
# Epoch [107/200], Batch [400/469] - Loss_D: 0.0768, Loss_G: 4.4066
# Epoch [108/200], Batch [0/469] - Loss_D: 0.0161, Loss_G: 7.5699
# Epoch [108/200], Batch [100/469] - Loss_D: 0.0152, Loss_G: 6.2893
# Epoch [108/200], Batch [200/469] - Loss_D: 0.0074, Loss_G: 6.8696
# Epoch [108/200], Batch [300/469] - Loss_D: 0.0146, Loss_G: 7.0979
# Epoch [108/200], Batch [400/469] - Loss_D: 0.0033, Loss_G: 7.4546
# Epoch [109/200], Batch [0/469] - Loss_D: 0.0077, Loss_G: 8.4324
# Epoch [109/200], Batch [100/469] - Loss_D: 0.3185, Loss_G: 10.7235
# Epoch [109/200], Batch [200/469] - Loss_D: 0.0289, Loss_G: 6.5458
# Epoch [109/200], Batch [300/469] - Loss_D: 0.0264, Loss_G: 5.7767
# Epoch [109/200], Batch [400/469] - Loss_D: 0.0087, Loss_G: 6.5867
# Epoch [110/200], Batch [0/469] - Loss_D: 0.0033, Loss_G: 7.1899
# Epoch [110/200], Batch [100/469] - Loss_D: 0.0121, Loss_G: 6.6527
# Epoch [110/200], Batch [200/469] - Loss_D: 0.0421, Loss_G: 6.0187
# Epoch [110/200], Batch [300/469] - Loss_D: 0.0055, Loss_G: 6.7902
# Epoch [110/200], Batch [400/469] - Loss_D: 0.0235, Loss_G: 6.0773
# Epoch [111/200], Batch [0/469] - Loss_D: 0.0336, Loss_G: 5.5889
# Epoch [111/200], Batch [100/469] - Loss_D: 0.0053, Loss_G: 7.0116
# Epoch [111/200], Batch [200/469] - Loss_D: 0.1819, Loss_G: 8.6647
# Epoch [111/200], Batch [300/469] - Loss_D: 0.2701, Loss_G: 3.0305
# Epoch [111/200], Batch [400/469] - Loss_D: 0.1401, Loss_G: 4.5514
# Epoch [112/200], Batch [0/469] - Loss_D: 0.0844, Loss_G: 5.0053
# Epoch [112/200], Batch [100/469] - Loss_D: 0.2247, Loss_G: 3.2917
# Epoch [112/200], Batch [200/469] - Loss_D: 0.0366, Loss_G: 5.9940
# Epoch [112/200], Batch [300/469] - Loss_D: 0.0087, Loss_G: 7.0819
# Epoch [112/200], Batch [400/469] - Loss_D: 0.0130, Loss_G: 5.8232
# Epoch [113/200], Batch [0/469] - Loss_D: 0.0125, Loss_G: 6.5711
# Epoch [113/200], Batch [100/469] - Loss_D: 0.0102, Loss_G: 6.7392
# Epoch [113/200], Batch [200/469] - Loss_D: 0.0465, Loss_G: 5.0484
# Epoch [113/200], Batch [300/469] - Loss_D: 0.0599, Loss_G: 5.3163
# Epoch [113/200], Batch [400/469] - Loss_D: 0.0113, Loss_G: 7.3766
# Epoch [114/200], Batch [0/469] - Loss_D: 0.0597, Loss_G: 6.8469
# Epoch [114/200], Batch [100/469] - Loss_D: 0.0371, Loss_G: 5.9998
# Epoch [114/200], Batch [200/469] - Loss_D: 0.0093, Loss_G: 6.7419
# Epoch [114/200], Batch [300/469] - Loss_D: 0.0336, Loss_G: 5.0127
# Epoch [114/200], Batch [400/469] - Loss_D: 0.0278, Loss_G: 7.3945
# Epoch [115/200], Batch [0/469] - Loss_D: 0.0175, Loss_G: 6.6666
# Epoch [115/200], Batch [100/469] - Loss_D: 0.0231, Loss_G: 5.8329
# Epoch [115/200], Batch [200/469] - Loss_D: 0.0230, Loss_G: 5.7103
# Epoch [115/200], Batch [300/469] - Loss_D: 0.0166, Loss_G: 6.2448
# Epoch [115/200], Batch [400/469] - Loss_D: 0.0047, Loss_G: 6.7465
# Epoch [116/200], Batch [0/469] - Loss_D: 0.0126, Loss_G: 6.2292
# Epoch [116/200], Batch [100/469] - Loss_D: 0.0177, Loss_G: 5.7687
# Epoch [116/200], Batch [200/469] - Loss_D: 0.0881, Loss_G: 4.3948
# Epoch [116/200], Batch [300/469] - Loss_D: 0.1288, Loss_G: 5.1590
# Epoch [116/200], Batch [400/469] - Loss_D: 0.2505, Loss_G: 4.6417
# Epoch [117/200], Batch [0/469] - Loss_D: 0.0386, Loss_G: 6.6040
# Epoch [117/200], Batch [100/469] - Loss_D: 0.0523, Loss_G: 5.6446
# Epoch [117/200], Batch [200/469] - Loss_D: 0.0133, Loss_G: 5.8733
# Epoch [117/200], Batch [300/469] - Loss_D: 0.0115, Loss_G: 7.2071
# Epoch [117/200], Batch [400/469] - Loss_D: 0.0122, Loss_G: 8.0028
# Epoch [118/200], Batch [0/469] - Loss_D: 0.0127, Loss_G: 6.2332
# Epoch [118/200], Batch [100/469] - Loss_D: 0.0034, Loss_G: 8.7277
# Epoch [118/200], Batch [200/469] - Loss_D: 0.0155, Loss_G: 5.3726
# Epoch [118/200], Batch [300/469] - Loss_D: 0.1729, Loss_G: 4.6297
# Epoch [118/200], Batch [400/469] - Loss_D: 0.0426, Loss_G: 6.0446
# Epoch [119/200], Batch [0/469] - Loss_D: 0.0213, Loss_G: 6.4580
# Epoch [119/200], Batch [100/469] - Loss_D: 0.0360, Loss_G: 6.1622
# Epoch [119/200], Batch [200/469] - Loss_D: 0.0352, Loss_G: 6.4010
# Epoch [119/200], Batch [300/469] - Loss_D: 0.0616, Loss_G: 4.4069
# Epoch [119/200], Batch [400/469] - Loss_D: 0.0452, Loss_G: 5.6051
# Epoch [120/200], Batch [0/469] - Loss_D: 0.0219, Loss_G: 5.7889
# Epoch [120/200], Batch [100/469] - Loss_D: 0.0100, Loss_G: 8.1091
# Epoch [120/200], Batch [200/469] - Loss_D: 0.0126, Loss_G: 7.6183
# Epoch [120/200], Batch [300/469] - Loss_D: 0.0255, Loss_G: 6.4087
# Epoch [120/200], Batch [400/469] - Loss_D: 0.0258, Loss_G: 6.0952
# Epoch [121/200], Batch [0/469] - Loss_D: 0.0548, Loss_G: 5.0270
# Epoch [121/200], Batch [100/469] - Loss_D: 0.0058, Loss_G: 8.1266
# Epoch [121/200], Batch [200/469] - Loss_D: 0.0044, Loss_G: 7.8130
# Epoch [121/200], Batch [300/469] - Loss_D: 0.0174, Loss_G: 6.1627
# Epoch [121/200], Batch [400/469] - Loss_D: 0.0912, Loss_G: 5.2428
# Epoch [122/200], Batch [0/469] - Loss_D: 0.0417, Loss_G: 5.4355
# Epoch [122/200], Batch [100/469] - Loss_D: 0.0124, Loss_G: 7.4388
# Epoch [122/200], Batch [200/469] - Loss_D: 0.0185, Loss_G: 6.0461
# Epoch [122/200], Batch [300/469] - Loss_D: 0.0250, Loss_G: 6.0761
# Epoch [122/200], Batch [400/469] - Loss_D: 0.1522, Loss_G: 3.1484
# Epoch [123/200], Batch [0/469] - Loss_D: 0.0265, Loss_G: 5.7198
# Epoch [123/200], Batch [100/469] - Loss_D: 0.0125, Loss_G: 6.3430
# Epoch [123/200], Batch [200/469] - Loss_D: 0.7872, Loss_G: 2.6399
# Epoch [123/200], Batch [300/469] - Loss_D: 0.0492, Loss_G: 5.4403
# Epoch [123/200], Batch [400/469] - Loss_D: 0.0958, Loss_G: 4.8397
# Epoch [124/200], Batch [0/469] - Loss_D: 0.0201, Loss_G: 6.5084
# Epoch [124/200], Batch [100/469] - Loss_D: 0.0120, Loss_G: 5.9348
# Epoch [124/200], Batch [200/469] - Loss_D: 0.0256, Loss_G: 5.7673
# Epoch [124/200], Batch [300/469] - Loss_D: 0.1529, Loss_G: 3.1037
# Epoch [124/200], Batch [400/469] - Loss_D: 0.0885, Loss_G: 5.2025
# Epoch [125/200], Batch [0/469] - Loss_D: 1.0435, Loss_G: 2.7127
# Epoch [125/200], Batch [100/469] - Loss_D: 0.0147, Loss_G: 6.6777
# Epoch [125/200], Batch [200/469] - Loss_D: 0.0118, Loss_G: 6.5360
# Epoch [125/200], Batch [300/469] - Loss_D: 0.0090, Loss_G: 6.7190
# Epoch [125/200], Batch [400/469] - Loss_D: 0.0101, Loss_G: 6.6234
# Epoch [126/200], Batch [0/469] - Loss_D: 0.0059, Loss_G: 6.8306
# Epoch [126/200], Batch [100/469] - Loss_D: 0.0053, Loss_G: 8.2554
# Epoch [126/200], Batch [200/469] - Loss_D: 0.1459, Loss_G: 4.5239
# Epoch [126/200], Batch [300/469] - Loss_D: 0.0224, Loss_G: 5.4883
# Epoch [126/200], Batch [400/469] - Loss_D: 0.0162, Loss_G: 6.2065
# Epoch [127/200], Batch [0/469] - Loss_D: 0.2529, Loss_G: 2.8144
# Epoch [127/200], Batch [100/469] - Loss_D: 0.0445, Loss_G: 5.1335
# Epoch [127/200], Batch [200/469] - Loss_D: 0.0180, Loss_G: 6.4244
# Epoch [127/200], Batch [300/469] - Loss_D: 0.0082, Loss_G: 6.6468
# Epoch [127/200], Batch [400/469] - Loss_D: 0.0143, Loss_G: 5.5366
# Epoch [128/200], Batch [0/469] - Loss_D: 0.0091, Loss_G: 6.7034
# Epoch [128/200], Batch [100/469] - Loss_D: 0.0036, Loss_G: 7.9856
# Epoch [128/200], Batch [200/469] - Loss_D: 0.0094, Loss_G: 7.1691
# Epoch [128/200], Batch [300/469] - Loss_D: 0.0076, Loss_G: 6.4029
# Epoch [128/200], Batch [400/469] - Loss_D: 0.0334, Loss_G: 5.2925
# Epoch [129/200], Batch [0/469] - Loss_D: 0.1521, Loss_G: 4.4953
# Epoch [129/200], Batch [100/469] - Loss_D: 0.0091, Loss_G: 6.2920
# Epoch [129/200], Batch [200/469] - Loss_D: 0.1962, Loss_G: 7.5184
# Epoch [129/200], Batch [300/469] - Loss_D: 0.0174, Loss_G: 6.3638
# Epoch [129/200], Batch [400/469] - Loss_D: 0.0106, Loss_G: 5.1122
# Epoch [130/200], Batch [0/469] - Loss_D: 0.1103, Loss_G: 4.8150
# Epoch [130/200], Batch [100/469] - Loss_D: 0.0451, Loss_G: 5.7082
# Epoch [130/200], Batch [200/469] - Loss_D: 0.0089, Loss_G: 7.3051
# Epoch [130/200], Batch [300/469] - Loss_D: 0.0296, Loss_G: 6.3660
# Epoch [130/200], Batch [400/469] - Loss_D: 0.0226, Loss_G: 6.0774
# Epoch [131/200], Batch [0/469] - Loss_D: 0.0099, Loss_G: 7.0082
# Epoch [131/200], Batch [100/469] - Loss_D: 0.0296, Loss_G: 5.5138
# Epoch [131/200], Batch [200/469] - Loss_D: 0.0264, Loss_G: 5.8055
# Epoch [131/200], Batch [300/469] - Loss_D: 0.0290, Loss_G: 5.7537
# Epoch [131/200], Batch [400/469] - Loss_D: 0.0099, Loss_G: 7.0936
# Epoch [132/200], Batch [0/469] - Loss_D: 0.0077, Loss_G: 7.4530
# Epoch [132/200], Batch [100/469] - Loss_D: 0.0064, Loss_G: 7.0650
# Epoch [132/200], Batch [200/469] - Loss_D: 0.0231, Loss_G: 5.8957
# Epoch [132/200], Batch [300/469] - Loss_D: 0.0075, Loss_G: 7.8061
# Epoch [132/200], Batch [400/469] - Loss_D: 0.0248, Loss_G: 6.2066
# Epoch [133/200], Batch [0/469] - Loss_D: 0.0041, Loss_G: 8.9849
# Epoch [133/200], Batch [100/469] - Loss_D: 0.0033, Loss_G: 7.7439
# Epoch [133/200], Batch [200/469] - Loss_D: 0.0166, Loss_G: 6.3402
# Epoch [133/200], Batch [300/469] - Loss_D: 0.5501, Loss_G: 4.9960
# Epoch [133/200], Batch [400/469] - Loss_D: 0.0472, Loss_G: 7.1665
# Epoch [134/200], Batch [0/469] - Loss_D: 0.0234, Loss_G: 6.4917
# Epoch [134/200], Batch [100/469] - Loss_D: 0.0202, Loss_G: 8.2391
# Epoch [134/200], Batch [200/469] - Loss_D: 0.0148, Loss_G: 8.5088
# Epoch [134/200], Batch [300/469] - Loss_D: 0.1503, Loss_G: 3.9836
# Epoch [134/200], Batch [400/469] - Loss_D: 0.0141, Loss_G: 6.2566
# Epoch [135/200], Batch [0/469] - Loss_D: 0.0768, Loss_G: 7.0865
# Epoch [135/200], Batch [100/469] - Loss_D: 0.0092, Loss_G: 6.4189
# Epoch [135/200], Batch [200/469] - Loss_D: 0.0177, Loss_G: 6.1883
# Epoch [135/200], Batch [300/469] - Loss_D: 0.0203, Loss_G: 6.3298
# Epoch [135/200], Batch [400/469] - Loss_D: 0.0095, Loss_G: 8.3938
# Epoch [136/200], Batch [0/469] - Loss_D: 0.0032, Loss_G: 8.1776
# Epoch [136/200], Batch [100/469] - Loss_D: 0.0110, Loss_G: 7.1666
# Epoch [136/200], Batch [200/469] - Loss_D: 0.0068, Loss_G: 6.5540
# Epoch [136/200], Batch [300/469] - Loss_D: 1.3665, Loss_G: 4.0526
# Epoch [136/200], Batch [400/469] - Loss_D: 0.0638, Loss_G: 4.5690
# Epoch [137/200], Batch [0/469] - Loss_D: 0.0768, Loss_G: 6.9356
# Epoch [137/200], Batch [100/469] - Loss_D: 0.0071, Loss_G: 7.1429
# Epoch [137/200], Batch [200/469] - Loss_D: 0.4391, Loss_G: 2.7035
# Epoch [137/200], Batch [300/469] - Loss_D: 0.1090, Loss_G: 4.9125
# Epoch [137/200], Batch [400/469] - Loss_D: 0.0324, Loss_G: 5.1260
# Epoch [138/200], Batch [0/469] - Loss_D: 0.0147, Loss_G: 7.1796
# Epoch [138/200], Batch [100/469] - Loss_D: 0.0281, Loss_G: 6.1878
# Epoch [138/200], Batch [200/469] - Loss_D: 0.0264, Loss_G: 6.3571
# Epoch [138/200], Batch [300/469] - Loss_D: 0.0056, Loss_G: 8.0124
# Epoch [138/200], Batch [400/469] - Loss_D: 0.0251, Loss_G: 6.2775
# Epoch [139/200], Batch [0/469] - Loss_D: 0.0160, Loss_G: 5.4245
# Epoch [139/200], Batch [100/469] - Loss_D: 0.0079, Loss_G: 7.8533
# Epoch [139/200], Batch [200/469] - Loss_D: 0.0172, Loss_G: 8.2817
# Epoch [139/200], Batch [300/469] - Loss_D: 0.0025, Loss_G: 7.7975
# Epoch [139/200], Batch [400/469] - Loss_D: 0.0170, Loss_G: 5.4553
# Epoch [140/200], Batch [0/469] - Loss_D: 0.2844, Loss_G: 3.1822
# Epoch [140/200], Batch [100/469] - Loss_D: 0.0411, Loss_G: 5.1986
# Epoch [140/200], Batch [200/469] - Loss_D: 0.0219, Loss_G: 6.1073
# Epoch [140/200], Batch [300/469] - Loss_D: 0.0335, Loss_G: 5.9297
# Epoch [140/200], Batch [400/469] - Loss_D: 0.0485, Loss_G: 6.9939
# Epoch [141/200], Batch [0/469] - Loss_D: 0.0066, Loss_G: 7.9536
# Epoch [141/200], Batch [100/469] - Loss_D: 0.0136, Loss_G: 7.6651
# Epoch [141/200], Batch [200/469] - Loss_D: 0.0429, Loss_G: 7.1286
# Epoch [141/200], Batch [300/469] - Loss_D: 0.5434, Loss_G: 2.8432
# Epoch [141/200], Batch [400/469] - Loss_D: 0.0258, Loss_G: 5.8293
# Epoch [142/200], Batch [0/469] - Loss_D: 0.0278, Loss_G: 5.9842
# Epoch [142/200], Batch [100/469] - Loss_D: 0.0142, Loss_G: 6.7986
# Epoch [142/200], Batch [200/469] - Loss_D: 0.0119, Loss_G: 6.6453
# Epoch [142/200], Batch [300/469] - Loss_D: 0.2842, Loss_G: 3.5312
# Epoch [142/200], Batch [400/469] - Loss_D: 0.0146, Loss_G: 7.0262
# Epoch [143/200], Batch [0/469] - Loss_D: 0.0311, Loss_G: 6.2127
# Epoch [143/200], Batch [100/469] - Loss_D: 0.0161, Loss_G: 6.3920
# Epoch [143/200], Batch [200/469] - Loss_D: 0.0059, Loss_G: 7.7853
# Epoch [143/200], Batch [300/469] - Loss_D: 0.0044, Loss_G: 6.7300
# Epoch [143/200], Batch [400/469] - Loss_D: 0.0386, Loss_G: 6.1531
# Epoch [144/200], Batch [0/469] - Loss_D: 0.0056, Loss_G: 7.8996
# Epoch [144/200], Batch [100/469] - Loss_D: 0.0062, Loss_G: 8.0228
# Epoch [144/200], Batch [200/469] - Loss_D: 0.0078, Loss_G: 7.1216
# Epoch [144/200], Batch [300/469] - Loss_D: 0.0057, Loss_G: 6.7903
# Epoch [144/200], Batch [400/469] - Loss_D: 0.3680, Loss_G: 3.2410
# Epoch [145/200], Batch [0/469] - Loss_D: 0.1234, Loss_G: 3.9142
# Epoch [145/200], Batch [100/469] - Loss_D: 0.0243, Loss_G: 6.4411
# Epoch [145/200], Batch [200/469] - Loss_D: 0.0620, Loss_G: 5.3931
# Epoch [145/200], Batch [300/469] - Loss_D: 0.0216, Loss_G: 5.7387
# Epoch [145/200], Batch [400/469] - Loss_D: 0.0501, Loss_G: 5.0558
# Epoch [146/200], Batch [0/469] - Loss_D: 0.0218, Loss_G: 6.1577
# Epoch [146/200], Batch [100/469] - Loss_D: 0.0196, Loss_G: 6.0317
# Epoch [146/200], Batch [200/469] - Loss_D: 0.0036, Loss_G: 7.6427
# Epoch [146/200], Batch [300/469] - Loss_D: 0.0371, Loss_G: 7.6078
# Epoch [146/200], Batch [400/469] - Loss_D: 0.0785, Loss_G: 4.5077
# Epoch [147/200], Batch [0/469] - Loss_D: 0.0953, Loss_G: 5.5977
# Epoch [147/200], Batch [100/469] - Loss_D: 0.0727, Loss_G: 5.1685
# Epoch [147/200], Batch [200/469] - Loss_D: 0.0146, Loss_G: 6.9026
# Epoch [147/200], Batch [300/469] - Loss_D: 0.0230, Loss_G: 5.1298
# Epoch [147/200], Batch [400/469] - Loss_D: 0.0048, Loss_G: 7.4302
# Epoch [148/200], Batch [0/469] - Loss_D: 0.0179, Loss_G: 9.5523
# Epoch [148/200], Batch [100/469] - Loss_D: 0.0015, Loss_G: 8.7269
# Epoch [148/200], Batch [200/469] - Loss_D: 0.0171, Loss_G: 6.1751
# Epoch [148/200], Batch [300/469] - Loss_D: 0.0109, Loss_G: 7.0004
# ...
# Epoch [152/200], Batch [200/469] - Loss_D: 0.0039, Loss_G: 7.2352
# Epoch [152/200], Batch [300/469] - Loss_D: 0.0198, Loss_G: 6.0633
# Epoch [152/200], Batch [400/469] - Loss_D: 0.0214, Loss_G: 6.2640
# Epoch [153/200], Batch [0/469] - Loss_D: 0.0084, Loss_G: 7.1215
# Epoch [153/200], Batch [100/469] - Loss_D: 0.0160, Loss_G: 6.3826
# Epoch [153/200], Batch [200/469] - Loss_D: 0.0085, Loss_G: 7.4359
# Epoch [153/200], Batch [300/469] - Loss_D: 0.0142, Loss_G: 6.6691
# Epoch [153/200], Batch [400/469] - Loss_D: 0.0074, Loss_G: 6.3587
# Epoch [154/200], Batch [0/469] - Loss_D: 0.5586, Loss_G: 2.3917
# Epoch [154/200], Batch [100/469] - Loss_D: 0.1362, Loss_G: 3.8948
# Epoch [154/200], Batch [200/469] - Loss_D: 0.0525, Loss_G: 4.7474
# Epoch [154/200], Batch [300/469] - Loss_D: 0.0115, Loss_G: 6.5948
# Epoch [154/200], Batch [400/469] - Loss_D: 0.0065, Loss_G: 6.5833
# Epoch [155/200], Batch [0/469] - Loss_D: 0.0154, Loss_G: 6.0417
# Epoch [155/200], Batch [100/469] - Loss_D: 0.0149, Loss_G: 8.1589
# Epoch [155/200], Batch [200/469] - Loss_D: 0.0045, Loss_G: 7.9490
# Epoch [155/200], Batch [300/469] - Loss_D: 0.0115, Loss_G: 6.3951
# Epoch [155/200], Batch [400/469] - Loss_D: 0.0067, Loss_G: 7.7949
# Epoch [156/200], Batch [0/469] - Loss_D: 0.0053, Loss_G: 6.4925
# Epoch [156/200], Batch [100/469] - Loss_D: 0.0036, Loss_G: 7.4657
# Epoch [156/200], Batch [200/469] - Loss_D: 0.0066, Loss_G: 7.0365
# Epoch [156/200], Batch [300/469] - Loss_D: 0.0141, Loss_G: 7.0006
# Epoch [156/200], Batch [400/469] - Loss_D: 0.1241, Loss_G: 4.7244
# Epoch [157/200], Batch [0/469] - Loss_D: 0.0659, Loss_G: 6.4522
# Epoch [157/200], Batch [100/469] - Loss_D: 0.0740, Loss_G: 4.2782
# Epoch [157/200], Batch [200/469] - Loss_D: 0.0231, Loss_G: 7.3866
# Epoch [157/200], Batch [300/469] - Loss_D: 0.0150, Loss_G: 6.1678
# Epoch [157/200], Batch [400/469] - Loss_D: 0.0094, Loss_G: 6.4825
# Epoch [158/200], Batch [0/469] - Loss_D: 0.0042, Loss_G: 7.1785
# Epoch [158/200], Batch [100/469] - Loss_D: 0.0265, Loss_G: 5.9158
# Epoch [158/200], Batch [200/469] - Loss_D: 0.0076, Loss_G: 6.7404
# Epoch [158/200], Batch [300/469] - Loss_D: 0.0024, Loss_G: 7.8342
# Epoch [158/200], Batch [400/469] - Loss_D: 0.0405, Loss_G: 6.9414
# Epoch [159/200], Batch [0/469] - Loss_D: 0.0060, Loss_G: 7.5743
# Epoch [159/200], Batch [100/469] - Loss_D: 0.0081, Loss_G: 7.1346
# Epoch [159/200], Batch [200/469] - Loss_D: 0.1902, Loss_G: 4.7606
# Epoch [159/200], Batch [300/469] - Loss_D: 0.0259, Loss_G: 5.8062
# Epoch [159/200], Batch [400/469] - Loss_D: 0.0229, Loss_G: 7.5612
# Epoch [160/200], Batch [0/469] - Loss_D: 0.0053, Loss_G: 6.7617
# Epoch [160/200], Batch [100/469] - Loss_D: 0.0089, Loss_G: 7.1278
# Epoch [160/200], Batch [200/469] - Loss_D: 0.0032, Loss_G: 8.8248
# Epoch [160/200], Batch [300/469] - Loss_D: 0.0123, Loss_G: 6.5003
# Epoch [160/200], Batch [400/469] - Loss_D: 0.0049, Loss_G: 7.6521
# Epoch [161/200], Batch [0/469] - Loss_D: 0.1202, Loss_G: 6.1541
# Epoch [161/200], Batch [100/469] - Loss_D: 0.0196, Loss_G: 6.0065
# Epoch [161/200], Batch [200/469] - Loss_D: 0.2159, Loss_G: 4.4047
# Epoch [161/200], Batch [300/469] - Loss_D: 0.0505, Loss_G: 5.6215
# Epoch [161/200], Batch [400/469] - Loss_D: 0.0865, Loss_G: 6.0841
# Epoch [162/200], Batch [0/469] - Loss_D: 0.0095, Loss_G: 7.6721
# Epoch [162/200], Batch [100/469] - Loss_D: 0.0165, Loss_G: 6.8964
# Epoch [162/200], Batch [200/469] - Loss_D: 0.0911, Loss_G: 4.3315
# Epoch [162/200], Batch [300/469] - Loss_D: 0.0091, Loss_G: 8.4757
# Epoch [162/200], Batch [400/469] - Loss_D: 0.0127, Loss_G: 6.0575
# Epoch [163/200], Batch [0/469] - Loss_D: 0.0149, Loss_G: 6.6152
# Epoch [163/200], Batch [100/469] - Loss_D: 0.0102, Loss_G: 7.4836
# Epoch [163/200], Batch [200/469] - Loss_D: 0.0154, Loss_G: 8.1624
# Epoch [163/200], Batch [300/469] - Loss_D: 0.0087, Loss_G: 6.8375
# Epoch [163/200], Batch [400/469] - Loss_D: 0.0256, Loss_G: 8.2404
# Epoch [164/200], Batch [0/469] - Loss_D: 0.0053, Loss_G: 7.2453
# Epoch [164/200], Batch [100/469] - Loss_D: 0.0019, Loss_G: 8.4415
# Epoch [164/200], Batch [200/469] - Loss_D: 0.0642, Loss_G: 5.1019
# Epoch [164/200], Batch [300/469] - Loss_D: 0.0213, Loss_G: 6.8900
# Epoch [164/200], Batch [400/469] - Loss_D: 0.0034, Loss_G: 8.6496
# Epoch [165/200], Batch [0/469] - Loss_D: 0.0062, Loss_G: 7.2217
# Epoch [165/200], Batch [100/469] - Loss_D: 0.0145, Loss_G: 6.6372
# Epoch [165/200], Batch [200/469] - Loss_D: 0.0051, Loss_G: 7.2869
# Epoch [165/200], Batch [300/469] - Loss_D: 0.0135, Loss_G: 6.4839
# Epoch [165/200], Batch [400/469] - Loss_D: 0.0127, Loss_G: 8.9025
# Epoch [166/200], Batch [0/469] - Loss_D: 0.0112, Loss_G: 8.2006
# Epoch [166/200], Batch [100/469] - Loss_D: 0.0041, Loss_G: 8.7339
# Epoch [166/200], Batch [200/469] - Loss_D: 0.2013, Loss_G: 4.2864
# Epoch [166/200], Batch [300/469] - Loss_D: 0.1455, Loss_G: 5.2618
# Epoch [166/200], Batch [400/469] - Loss_D: 0.0991, Loss_G: 4.8626
# Epoch [167/200], Batch [0/469] - Loss_D: 0.0576, Loss_G: 4.8747
# Epoch [167/200], Batch [100/469] - Loss_D: 0.0222, Loss_G: 5.5850
# Epoch [167/200], Batch [200/469] - Loss_D: 0.0276, Loss_G: 6.3665
# Epoch [167/200], Batch [300/469] - Loss_D: 0.0079, Loss_G: 6.6129
# Epoch [167/200], Batch [400/469] - Loss_D: 0.0116, Loss_G: 6.4876
# Epoch [168/200], Batch [0/469] - Loss_D: 0.0159, Loss_G: 6.7913
# Epoch [168/200], Batch [100/469] - Loss_D: 0.0036, Loss_G: 7.5461
# Epoch [168/200], Batch [200/469] - Loss_D: 0.0112, Loss_G: 6.9853
# Epoch [168/200], Batch [300/469] - Loss_D: 0.2150, Loss_G: 4.0543
# Epoch [168/200], Batch [400/469] - Loss_D: 0.2896, Loss_G: 5.9030
# Epoch [169/200], Batch [0/469] - Loss_D: 0.2243, Loss_G: 3.6451
# Epoch [169/200], Batch [100/469] - Loss_D: 0.0656, Loss_G: 5.1953
# Epoch [169/200], Batch [200/469] - Loss_D: 0.0155, Loss_G: 6.3976
# Epoch [169/200], Batch [300/469] - Loss_D: 0.0069, Loss_G: 6.9747
# Epoch [169/200], Batch [400/469] - Loss_D: 0.0032, Loss_G: 8.9105
# Epoch [170/200], Batch [0/469] - Loss_D: 0.0133, Loss_G: 8.3167
# Epoch [170/200], Batch [100/469] - Loss_D: 0.0090, Loss_G: 6.2501
# Epoch [170/200], Batch [200/469] - Loss_D: 0.0184, Loss_G: 6.8562
# Epoch [170/200], Batch [300/469] - Loss_D: 0.0071, Loss_G: 8.5484
# Epoch [170/200], Batch [400/469] - Loss_D: 0.0048, Loss_G: 7.2797
# Epoch [171/200], Batch [0/469] - Loss_D: 0.0052, Loss_G: 8.2609
# Epoch [171/200], Batch [100/469] - Loss_D: 0.2569, Loss_G: 6.4413
# Epoch [171/200], Batch [200/469] - Loss_D: 0.0079, Loss_G: 8.5070
# Epoch [171/200], Batch [300/469] - Loss_D: 0.0045, Loss_G: 7.4954
# Epoch [171/200], Batch [400/469] - Loss_D: 0.0836, Loss_G: 4.5829
# Epoch [172/200], Batch [0/469] - Loss_D: 0.0338, Loss_G: 5.1330
# Epoch [172/200], Batch [100/469] - Loss_D: 0.0361, Loss_G: 5.2611
# Epoch [172/200], Batch [200/469] - Loss_D: 0.0320, Loss_G: 5.8683
# Epoch [172/200], Batch [300/469] - Loss_D: 0.0049, Loss_G: 7.5378
# Epoch [172/200], Batch [400/469] - Loss_D: 0.0079, Loss_G: 7.2857
# Epoch [173/200], Batch [0/469] - Loss_D: 0.0093, Loss_G: 6.3330
# Epoch [173/200], Batch [100/469] - Loss_D: 0.0153, Loss_G: 7.9633
# Epoch [173/200], Batch [200/469] - Loss_D: 0.0476, Loss_G: 5.8970
# Epoch [173/200], Batch [300/469] - Loss_D: 0.0061, Loss_G: 7.0268
# Epoch [173/200], Batch [400/469] - Loss_D: 0.0331, Loss_G: 5.4397
# Epoch [174/200], Batch [0/469] - Loss_D: 0.0132, Loss_G: 5.8577
# Epoch [174/200], Batch [100/469] - Loss_D: 0.0109, Loss_G: 6.9413
# Epoch [174/200], Batch [200/469] - Loss_D: 0.0093, Loss_G: 7.5821
# Epoch [174/200], Batch [300/469] - Loss_D: 0.0162, Loss_G: 6.7183
# Epoch [174/200], Batch [400/469] - Loss_D: 0.0109, Loss_G: 6.6938
# Epoch [175/200], Batch [0/469] - Loss_D: 0.0055, Loss_G: 8.0588
# Epoch [175/200], Batch [100/469] - Loss_D: 0.0042, Loss_G: 8.1200
# Epoch [175/200], Batch [200/469] - Loss_D: 0.3277, Loss_G: 5.5752
# Epoch [175/200], Batch [300/469] - Loss_D: 0.0909, Loss_G: 6.3499
# Epoch [175/200], Batch [400/469] - Loss_D: 0.0178, Loss_G: 6.8649
# Epoch [176/200], Batch [0/469] - Loss_D: 0.0026, Loss_G: 7.7851
# Epoch [176/200], Batch [100/469] - Loss_D: 0.0681, Loss_G: 5.6244
# Epoch [176/200], Batch [200/469] - Loss_D: 0.0075, Loss_G: 7.9457
# Epoch [176/200], Batch [300/469] - Loss_D: 0.0067, Loss_G: 7.1111
# Epoch [176/200], Batch [400/469] - Loss_D: 0.0018, Loss_G: 9.0320
# Epoch [177/200], Batch [0/469] - Loss_D: 0.0088, Loss_G: 6.6934
# Epoch [177/200], Batch [100/469] - Loss_D: 0.0045, Loss_G: 6.5637
# Epoch [177/200], Batch [200/469] - Loss_D: 0.0097, Loss_G: 6.9569
# Epoch [177/200], Batch [300/469] - Loss_D: 0.1537, Loss_G: 3.6590
# Epoch [177/200], Batch [400/469] - Loss_D: 0.0442, Loss_G: 5.9605
# Epoch [178/200], Batch [0/469] - Loss_D: 0.0203, Loss_G: 7.1404
# Epoch [178/200], Batch [100/469] - Loss_D: 0.0547, Loss_G: 5.1408
# Epoch [178/200], Batch [200/469] - Loss_D: 0.0667, Loss_G: 6.3923
# Epoch [178/200], Batch [300/469] - Loss_D: 0.0080, Loss_G: 7.2144
# Epoch [178/200], Batch [400/469] - Loss_D: 0.0302, Loss_G: 5.7851
# Epoch [179/200], Batch [0/469] - Loss_D: 0.0057, Loss_G: 7.5382
# Epoch [179/200], Batch [100/469] - Loss_D: 0.0533, Loss_G: 5.7494
# Epoch [179/200], Batch [200/469] - Loss_D: 0.0146, Loss_G: 7.9146
# Epoch [179/200], Batch [300/469] - Loss_D: 0.0043, Loss_G: 9.0510
# Epoch [179/200], Batch [400/469] - Loss_D: 0.0078, Loss_G: 10.3508
# Epoch [180/200], Batch [0/469] - Loss_D: 0.0016, Loss_G: 9.8542
# Epoch [180/200], Batch [100/469] - Loss_D: 0.0081, Loss_G: 9.0614
# Epoch [180/200], Batch [200/469] - Loss_D: 0.0127, Loss_G: 6.8142
# Epoch [180/200], Batch [300/469] - Loss_D: 0.0016, Loss_G: 8.4901
# Epoch [180/200], Batch [400/469] - Loss_D: 1.5933, Loss_G: 1.8056
# Epoch [181/200], Batch [0/469] - Loss_D: 0.1275, Loss_G: 4.5450
# Epoch [181/200], Batch [100/469] - Loss_D: 0.0284, Loss_G: 5.8710
# Epoch [181/200], Batch [200/469] - Loss_D: 0.0073, Loss_G: 6.8302
# Epoch [181/200], Batch [300/469] - Loss_D: 0.0182, Loss_G: 5.8949
# Epoch [181/200], Batch [400/469] - Loss_D: 0.0529, Loss_G: 4.6008
# Epoch [182/200], Batch [0/469] - Loss_D: 0.0493, Loss_G: 5.2509
# Epoch [182/200], Batch [100/469] - Loss_D: 0.0071, Loss_G: 7.3206
# Epoch [182/200], Batch [200/469] - Loss_D: 0.0034, Loss_G: 9.1104
# Epoch [182/200], Batch [300/469] - Loss_D: 0.0051, Loss_G: 7.9326
# Epoch [182/200], Batch [400/469] - Loss_D: 0.0059, Loss_G: 7.7985
# Epoch [183/200], Batch [0/469] - Loss_D: 0.0215, Loss_G: 6.6745
# Epoch [183/200], Batch [100/469] - Loss_D: 0.0287, Loss_G: 6.8660
# Epoch [183/200], Batch [200/469] - Loss_D: 0.2185, Loss_G: 4.3000
# Epoch [183/200], Batch [300/469] - Loss_D: 0.1134, Loss_G: 5.2972
# Epoch [183/200], Batch [400/469] - Loss_D: 0.0232, Loss_G: 6.4475
# Epoch [184/200], Batch [0/469] - Loss_D: 0.1466, Loss_G: 5.0633
# Epoch [184/200], Batch [100/469] - Loss_D: 0.0237, Loss_G: 6.1474
# Epoch [184/200], Batch [200/469] - Loss_D: 0.0409, Loss_G: 5.6699
# Epoch [184/200], Batch [300/469] - Loss_D: 0.0121, Loss_G: 6.5319
# Epoch [184/200], Batch [400/469] - Loss_D: 0.0084, Loss_G: 7.9101
# Epoch [185/200], Batch [0/469] - Loss_D: 0.0047, Loss_G: 7.2319
# Epoch [185/200], Batch [100/469] - Loss_D: 0.0060, Loss_G: 7.1327
# Epoch [185/200], Batch [200/469] - Loss_D: 0.0058, Loss_G: 6.8253
# Epoch [185/200], Batch [300/469] - Loss_D: 0.0280, Loss_G: 6.7827
# Epoch [185/200], Batch [400/469] - Loss_D: 0.0827, Loss_G: 8.0852
# Epoch [186/200], Batch [0/469] - Loss_D: 0.0020, Loss_G: 8.6229
# Epoch [186/200], Batch [100/469] - Loss_D: 0.1013, Loss_G: 8.5670
# Epoch [186/200], Batch [200/469] - Loss_D: 0.0719, Loss_G: 4.4007
# Epoch [186/200], Batch [300/469] - Loss_D: 0.0579, Loss_G: 6.1709
# Epoch [186/200], Batch [400/469] - Loss_D: 0.0149, Loss_G: 6.0638
# Epoch [187/200], Batch [0/469] - Loss_D: 0.0167, Loss_G: 7.7092
# Epoch [187/200], Batch [100/469] - Loss_D: 0.0069, Loss_G: 7.7690
# Epoch [187/200], Batch [200/469] - Loss_D: 0.0325, Loss_G: 6.8011
# Epoch [187/200], Batch [300/469] - Loss_D: 0.0101, Loss_G: 7.0907
# Epoch [187/200], Batch [400/469] - Loss_D: 0.0078, Loss_G: 6.8263
# Epoch [188/200], Batch [0/469] - Loss_D: 0.0065, Loss_G: 6.9352
# Epoch [188/200], Batch [100/469] - Loss_D: 0.0281, Loss_G: 6.1923
# Epoch [188/200], Batch [200/469] - Loss_D: 0.0045, Loss_G: 6.9397
# Epoch [188/200], Batch [300/469] - Loss_D: 0.0109, Loss_G: 7.9534
# Epoch [188/200], Batch [400/469] - Loss_D: 3.8345, Loss_G: 12.8375
# Epoch [189/200], Batch [0/469] - Loss_D: 0.0414, Loss_G: 5.7401
# Epoch [189/200], Batch [100/469] - Loss_D: 0.0331, Loss_G: 5.5859
# Epoch [189/200], Batch [200/469] - Loss_D: 0.0364, Loss_G: 7.1655
# Epoch [189/200], Batch [300/469] - Loss_D: 0.0173, Loss_G: 6.1961
# Epoch [189/200], Batch [400/469] - Loss_D: 0.0151, Loss_G: 7.7500
# Epoch [190/200], Batch [0/469] - Loss_D: 0.0126, Loss_G: 7.6500
# Epoch [190/200], Batch [100/469] - Loss_D: 0.0042, Loss_G: 7.9627
# Epoch [190/200], Batch [200/469] - Loss_D: 0.0017, Loss_G: 8.7257
# Epoch [190/200], Batch [300/469] - Loss_D: 0.0315, Loss_G: 7.4652
# Epoch [190/200], Batch [400/469] - Loss_D: 0.0153, Loss_G: 6.4065
# Epoch [191/200], Batch [0/469] - Loss_D: 0.0015, Loss_G: 8.2861
# Epoch [191/200], Batch [100/469] - Loss_D: 0.0026, Loss_G: 7.5943
# Epoch [191/200], Batch [200/469] - Loss_D: 0.0115, Loss_G: 6.6576
# Epoch [191/200], Batch [300/469] - Loss_D: 0.0844, Loss_G: 9.9882
# Epoch [191/200], Batch [400/469] - Loss_D: 0.2623, Loss_G: 5.8205
# Epoch [192/200], Batch [0/469] - Loss_D: 0.0222, Loss_G: 6.4083
# Epoch [192/200], Batch [100/469] - Loss_D: 0.0170, Loss_G: 6.7279
# Epoch [192/200], Batch [200/469] - Loss_D: 0.0081, Loss_G: 7.4863
# Epoch [192/200], Batch [300/469] - Loss_D: 0.0028, Loss_G: 8.0755
# Epoch [192/200], Batch [400/469] - Loss_D: 0.0024, Loss_G: 8.4824
# Epoch [193/200], Batch [0/469] - Loss_D: 0.0152, Loss_G: 6.4260
# Epoch [193/200], Batch [100/469] - Loss_D: 0.0208, Loss_G: 6.1608
# Epoch [193/200], Batch [200/469] - Loss_D: 0.0491, Loss_G: 5.8260
# Epoch [193/200], Batch [300/469] - Loss_D: 0.0787, Loss_G: 5.4172
# Epoch [193/200], Batch [400/469] - Loss_D: 0.0132, Loss_G: 5.9294
# Epoch [194/200], Batch [0/469] - Loss_D: 0.0038, Loss_G: 7.8248
# Epoch [194/200], Batch [100/469] - Loss_D: 0.2867, Loss_G: 4.4758
# Epoch [194/200], Batch [200/469] - Loss_D: 0.0363, Loss_G: 5.4325
# Epoch [194/200], Batch [300/469] - Loss_D: 0.0119, Loss_G: 6.6121
# Epoch [194/200], Batch [400/469] - Loss_D: 0.0090, Loss_G: 8.5326
# Epoch [195/200], Batch [0/469] - Loss_D: 0.0204, Loss_G: 5.8802
# Epoch [195/200], Batch [100/469] - Loss_D: 0.0092, Loss_G: 6.5409
# Epoch [195/200], Batch [200/469] - Loss_D: 0.0140, Loss_G: 6.2667
# Epoch [195/200], Batch [300/469] - Loss_D: 0.0060, Loss_G: 7.0458
# Epoch [195/200], Batch [400/469] - Loss_D: 0.0196, Loss_G: 8.3871
# Epoch [196/200], Batch [0/469] - Loss_D: 0.0110, Loss_G: 5.7811
# Epoch [196/200], Batch [100/469] - Loss_D: 0.0067, Loss_G: 6.6785
# Epoch [196/200], Batch [200/469] - Loss_D: 0.0071, Loss_G: 7.9330
# Epoch [196/200], Batch [300/469] - Loss_D: 0.0880, Loss_G: 4.4630
# Epoch [196/200], Batch [400/469] - Loss_D: 0.0528, Loss_G: 5.7349
# Epoch [197/200], Batch [0/469] - Loss_D: 0.0199, Loss_G: 6.7880
# Epoch [197/200], Batch [100/469] - Loss_D: 0.0064, Loss_G: 8.0651
# Epoch [197/200], Batch [200/469] - Loss_D: 0.0447, Loss_G: 5.6549
# Epoch [197/200], Batch [300/469] - Loss_D: 0.0069, Loss_G: 6.6825
# Epoch [197/200], Batch [400/469] - Loss_D: 0.0238, Loss_G: 5.9997
# Epoch [198/200], Batch [0/469] - Loss_D: 0.0092, Loss_G: 7.2764
# Epoch [198/200], Batch [100/469] - Loss_D: 0.0354, Loss_G: 6.4030
# Epoch [198/200], Batch [200/469] - Loss_D: 0.0075, Loss_G: 7.1671
# Epoch [198/200], Batch [300/469] - Loss_D: 0.0026, Loss_G: 8.1075
# Epoch [198/200], Batch [400/469] - Loss_D: 0.0067, Loss_G: 8.9797
# Epoch [199/200], Batch [0/469] - Loss_D: 0.0059, Loss_G: 7.5128
# Epoch [199/200], Batch [100/469] - Loss_D: 0.0397, Loss_G: 8.4511
# Epoch [199/200], Batch [200/469] - Loss_D: 0.0686, Loss_G: 5.1298
# Epoch [199/200], Batch [300/469] - Loss_D: 0.0201, Loss_G: 7.0681
# Epoch [199/200], Batch [400/469] - Loss_D: 0.0282, Loss_G: 6.0856
# Epoch [200/200], Batch [0/469] - Loss_D: 0.0126, Loss_G: 6.2510
# Epoch [200/200], Batch [100/469] - Loss_D: 0.0131, Loss_G: 7.5738
# Epoch [200/200], Batch [200/469] - Loss_D: 0.0128, Loss_G: 6.1723
# Epoch [200/200], Batch [300/469] - Loss_D: 0.0104, Loss_G: 6.5258
# Epoch [200/200], Batch [400/469] - Loss_D: 0.1351, Loss_G: 6.7539
# Training finished.

# %%
## Final Generated Images
with torch.no_grad():
    final_noise = torch.randn(64, latent_dim, device=device)
    final_generated = netGen(final_noise).detach().cpu()
grid_generated = utils.make_grid(final_generated[:64], nrow=8, normalize=True)
plt.figure(figsize=(8,8))
plt.imshow(np.transpose(grid_generated, (1,2,0)))
plt.title("Final Generated Images")
plt.axis("off")
plt.show()

# %% [markdown]
# Model Performance Evaluation Plot Loss Curve

# %%
# Plotting Generator and Discriminator Loss
plt.figure(figsize=(10, 5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(Gen_losses, label="Generator Loss")
plt.plot(Dis_losses, label="Discriminator Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# Comparision Of Final Generated Images with Real Images

# %%
# Show final generated images
with torch.no_grad():
    final_noise = torch.randn(64, latent_dim, device=device)
    final_generated = netGen(final_noise).detach().cpu()
show_images(final_generated[:64], "Final Generated Images")

# Show real images for comparison
real_samples, _ = next(iter(dataloader))
show_images(real_samples[:64], "Real MNIST Images")

# %%
# Batch of real images for comparisions

real_samples, _ = next(iter(dataloader))
grid_real = utils.make_grid(real_samples[:64], nrow=8, normalize=True)
plt.figure(figsize=(8,8))
plt.imshow(np.transpose(grid_real, (1,2,0)))
plt.title("Real MNIST Images")
plt.axis("off")
plt.show()

# %%
# Save Generator Model
save_path = "C:/Users/HP/OneDrive/Documents/GAN's Project/model/model.pth"
# Create parent directory if it does not exist
os.makedirs(os.path.dirname(save_path), exist_ok=True)
torch.save(netGen.state_dict(), save_path)
print(f"Generator model saved to {save_path}")
# Out:
# Generator model saved to C:/Users/HP/OneDrive/Documents/GAN's Project/model/model.pth
